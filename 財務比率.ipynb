# %% [markdown]
# # 取得原始資料

# %% [markdown]
# ## 比率

# %%
import requests
import numpy as np

stock_ids = np.array(input("請輸入股票代碼，並以空格區分: ").split(), dtype = int) 
# map(int, input("請輸入股票代碼，並以空格區分: ").split())

ratio = input("請輸入想要查看的比率: ")

"""
以下的比率會先跟自己比再跟產業平均比。
DebtRatio 判斷是否小於0.5，大於等於的話再和產業平均比，再大於等於產業平均就示警，越小越安全。
LongTermLiabilitiesRatio 判斷是否大於1，大於產業平均再警示。越大代表有較高的融資風險，但也可能是對未來樂觀；小於1代表財務結構安全性高。
CurrentRatio 判斷是否小於1，小於的話要再和產業平均比，再小於就警示。大於1是安全的，否則也要看是否大於產業平均。
QuickRatio 判斷是否小於1，小於的話要再和產業平均比，再小於就警示。大於1是安全的，否則也要看是否大於產業平均。
InterestCoverage 判斷是小於5，小於的話要再和產業平均比，再小於就警示。
AccountsReceivableTurnover 這個不判斷
AccountsReceivableTurnoverDay 這個不判斷
InventoryTurnover 這個不判斷
InventoryTurnoverDay 這個不判斷
TotalAssetTurnover 判斷是否小於0.5，小於的話要再和產業平均比，再小於就警示。
GrossMargin 
OperatingMargin 
NetIncomeMargin 判斷這一期是否小於去年同期，是的話再和產業是否衰退比，產業成長就警示。
ROA 判斷是否小於6%，小於的話，再和產業平均比，再小於就警示。
ROE 判斷是否小於8%，小於的話，再和產業平均比，再小於就警示。
OperatingCashflowToCurrentLiability 判斷是否小於100%，小於的話，再和產業平均比，再小於就警示。
OperatingCashflowToLiability 
OperatingCashflowToNetProfit 判斷是否小於80%，小於的話，再和產業平均比，再小於就警示。
"""

data = {
    "compareItem": ratio,
    "quarter": "true",
    "ylabel": "%",
    "ys": "0",
    "revenue": "true",
    "bcodeAvg": "true",
    "companyAvg": "true",
    "companyId": list(stock_ids)
}

response = requests.post("https://mopsfin.twse.com.tw/compare/data", data = data)
response
# Out:
# <Response [200]>

# %%
data = response.json()

values = data["graphData"]
len(values)
# Out:
# 3

# %%
response.json()#.text
# Out:
# {'xaxisList': ['2013Q1',
#   '2013Q2',
#   '2013Q3',
#   '2013Q4',
#   '2014Q1',
#   '2014Q2',
#   '2014Q3',
#   '2014Q4',
#   '2015Q1',
#   '2015Q2',
#   '2015Q3',
#   '2015Q4',
#   '2016Q1',
#   '2016Q2',
#   '2016Q3',
#   '2016Q4',
#   '2017Q1',
#   '2017Q2',
#   '2017Q3',
#   '2017Q4',
#   '2018Q1',
#   '2018Q2',
#   '2018Q3',
#   '2018Q4',
#   '2019Q1',
#   '2019Q2',
#   '2019Q3',
#   '2019Q4',
#   '2020Q1',
#   '2020Q2',
#   '2020Q3',
#   '2020Q4',
#   '2021Q1',
#   '2021Q2',
#   '2021Q3',
#   '2021Q4',
#   '2022Q1',
#   '2022Q2',
#   '2022Q3',
#   '2022Q4',
#   '2023Q1',
#   '2023Q2',
#   '2023Q3',
#   '2023Q4',
#   '2024Q1',
#   '2024Q2',
#   '2024Q3'],
#  'ylabel': '%',
#  'yaxisLabel': '',
#  'qnumber': '1',
#  'json': '{"xaxisList":["2013Q1","2013Q2","2013Q3","2013Q4","2014Q1","2014Q2","2014Q3","2014Q4","2015Q1","2015Q2","2015Q3","2015Q4","2016Q1","2016Q2","2016Q3","2016Q4","2017Q1","2017Q2","2017Q3","2017Q4","2018Q1","2018Q2","2018Q3","2018Q4","2019Q1","2019Q2","2019Q3","2019Q4","2020Q1","2020Q2","2020Q3","2020Q4","2021Q1","2021Q2","2021Q3","2021Q4","2022Q1","2022Q2","2022Q3","2022Q4","2023Q1","2023Q2","2023Q3","2023Q4","2024Q1","2024Q2","2024Q3"],"ylabel":"%","yaxisLabel":"","graphData":[{"data":[[0,27.60,"C"],[1,36.21,"C"],[2,31.71,"C"],[3,32.88,"C"],[4,30.86,"C"],[5,34.80,"C"],[6,29.14,"C"],[7,30.06,"C"],[8,27.81,"C"],[9,33.70,"C"],[10,26.98,"C"],[11,26.24,"C"],[12,25.81,"C"],[13,33.65,"C"],[14,25.30,"C"],[15,26.31,"C"],[16,24.73,"C"],[17,32.42,"C"],[18,22.27,"C"],[19,23.55,"C"],[20,21.60,"C"],[21,27.41,"C"],[22,20.00,"C"],[23,19.74,"C"],[24,20.29,"C"],[25,30.59,"C"],[26,25.62,"C"],[27,28.38,"C"],[28,28.43,"C"],[29,29.71,"C"],[30,32.15,"C"],[31,32.97,"C"],[32,33.51,"C"],[33,35.53,"C"],[34,37.63,"C"],[35,41.73,"C"],[36,41.86,"C"],[37,42.23,"C"],[38,40.73,"C"],[39,40.37,"C"],[40,38.70,"C"],[41,37.75,"C"],[42,38.50,"C"],[43,37.04,"C"],[44,36.67,"C"],[45,36.14,"C"],[46,34.77,"C"]],"label":"台積電"},{"data":[[0,27.6,"C"],[1,36.21,"C"],[2,31.71,"C"],[3,32.88,"C"],[4,30.86,"C"],[5,34.8,"C"],[6,29.14,"C"],[7,30.06,"C"],[8,27.81,"C"],[9,33.7,"C"],[10,26.98,"C"],[11,26.24,"C"],[12,25.81,"C"],[13,33.65,"C"],[14,25.3,"C"],[15,26.31,"C"],[16,24.73,"C"],[17,32.42,"C"],[18,22.27,"C"],[19,23.55,"C"],[20,21.6,"C"],[21,27.41,"C"],[22,20.0,"C"],[23,19.74,"C"],[24,20.29,"C"],[25,30.59,"C"],[26,25.62,"C"],[27,28.38,"C"],[28,28.43,"C"],[29,29.71,"C"],[30,32.15,"C"],[31,32.97,"C"],[32,33.51,"C"],[33,35.53,"C"],[34,37.63,"C"],[35,41.73,"C"],[36,41.86,"C"],[37,42.23,"C"],[38,40.73,"C"],[39,40.37,"C"],[40,38.7,"C"],[41,37.75,"C"],[42,38.5,"C"],[43,37.04,"C"],[44,36.67,"C"],[45,36.14,"C"],[46,34.77,"C"]],"label":"公司平均數"},{"data":[[0,32.01,null],[1,37.84,null],[2,34.33,null],[3,34.62,null],[4,32.94,null],[5,37.11,null],[6,33.27,null],[7,32.78,null],[8,31.06,null],[9,36.39,null],[10,31.30,null],[11,30.44,null],[12,29.93,null],[13,36.82,null],[14,31.91,null],[15,33.02,null],[16,31.72,null],[17,36.76,null],[18,30.71,null],[19,30.31,null],[20,28.84,null],[21,36.97,null],[22,32.89,null],[23,31.53,null],[24,31.26,null],[25,38.31,null],[26,35.22,null],[27,36.06,null],[28,35.95,null],[29,37.54,null],[30,37.30,null],[31,36.98,null],[32,36.97,null],[33,40.50,null],[34,40.71,null],[35,42.22,null],[36,42.73,null],[37,45.25,null],[38,41.80,null],[39,40.60,null],[40,40.99,null],[41,41.34,null],[42,40.17,null],[43,39.29,null],[44,39.19,null],[45,39.71,null],[46,37.83,null],[null,null,null],[null,null,null]],"label":"半導體業"}],"showNameList":["2330 台積電 (上市半導體業)"],"checkedNameList":["2330 台積電 (上市半導體業)","公司平均數","半導體業"],"extraNameList":["公司平均數","半導體業"]}',
#  'graphData': [{'data': [[0, 27.6, 'C'],
#     [1, 36.21, 'C'],
#     [2, 31.71, 'C'],
#     [3, 32.88, 'C'],
#     [4, 30.86, 'C'],
#     [5, 34.8, 'C'],
#     [6, 29.14, 'C'],
#     [7, 30.06, 'C'],
#     [8, 27.81, 'C'],
#     [9, 33.7, 'C'],
#     [10, 26.98, 'C'],
#     [11, 26.24, 'C'],
#     [12, 25.81, 'C'],
#     [13, 33.65, 'C'],
#     [14, 25.3, 'C'],
#     [15, 26.31, 'C'],
#     [16, 24.73, 'C'],
#     [17, 32.42, 'C'],
#     [18, 22.27, 'C'],
#     [19, 23.55, 'C'],
#     [20, 21.6, 'C'],
#     [21, 27.41, 'C'],
#     [22, 20.0, 'C'],
#     [23, 19.74, 'C'],
#     [24, 20.29, 'C'],
#     [25, 30.59, 'C'],
#     [26, 25.62, 'C'],
#     [27, 28.38, 'C'],
#     [28, 28.43, 'C'],
#     [29, 29.71, 'C'],
#     [30, 32.15, 'C'],
#     [31, 32.97, 'C'],
#     [32, 33.51, 'C'],
#     [33, 35.53, 'C'],
#     [34, 37.63, 'C'],
#     [35, 41.73, 'C'],
#     [36, 41.86, 'C'],
#     [37, 42.23, 'C'],
#     [38, 40.73, 'C'],
#     [39, 40.37, 'C'],
#     [40, 38.7, 'C'],
#     [41, 37.75, 'C'],
#     [42, 38.5, 'C'],
#     [43, 37.04, 'C'],
#     [44, 36.67, 'C'],
#     [45, 36.14, 'C'],
#     [46, 34.77, 'C']],
#    'label': '台積電'},
#   {'data': [[0, 27.6, 'C'],
#     [1, 36.21, 'C'],
#     [2, 31.71, 'C'],
#     [3, 32.88, 'C'],
#     [4, 30.86, 'C'],
#     [5, 34.8, 'C'],
#     [6, 29.14, 'C'],
#     [7, 30.06, 'C'],
#     [8, 27.81, 'C'],
#     [9, 33.7, 'C'],
#     [10, 26.98, 'C'],
#     [11, 26.24, 'C'],
#     [12, 25.81, 'C'],
#     [13, 33.65, 'C'],
#     [14, 25.3, 'C'],
#     [15, 26.31, 'C'],
#     [16, 24.73, 'C'],
#     [17, 32.42, 'C'],
#     [18, 22.27, 'C'],
#     [19, 23.55, 'C'],
#     [20, 21.6, 'C'],
#     [21, 27.41, 'C'],
#     [22, 20.0, 'C'],
#     [23, 19.74, 'C'],
#     [24, 20.29, 'C'],
#     [25, 30.59, 'C'],
#     [26, 25.62, 'C'],
#     [27, 28.38, 'C'],
#     [28, 28.43, 'C'],
#     [29, 29.71, 'C'],
#     [30, 32.15, 'C'],
#     [31, 32.97, 'C'],
#     [32, 33.51, 'C'],
#     [33, 35.53, 'C'],
#     [34, 37.63, 'C'],
#     [35, 41.73, 'C'],
#     [36, 41.86, 'C'],
#     [37, 42.23, 'C'],
#     [38, 40.73, 'C'],
#     [39, 40.37, 'C'],
#     [40, 38.7, 'C'],
#     [41, 37.75, 'C'],
#     [42, 38.5, 'C'],
#     [43, 37.04, 'C'],
#     [44, 36.67, 'C'],
#     [45, 36.14, 'C'],
#     [46, 34.77, 'C']],
#    'label': '公司平均數'},
#   {'data': [[0, 32.01, None],
#     [1, 37.84, None],
#     [2, 34.33, None],
#     [3, 34.62, None],
#     [4, 32.94, None],
#     [5, 37.11, None],
#     [6, 33.27, None],
#     [7, 32.78, None],
#     [8, 31.06, None],
#     [9, 36.39, None],
#     [10, 31.3, None],
#     [11, 30.44, None],
#     [12, 29.93, None],
#     [13, 36.82, None],
#     [14, 31.91, None],
#     [15, 33.02, None],
#     [16, 31.72, None],
#     [17, 36.76, None],
#     [18, 30.71, None],
#     [19, 30.31, None],
#     [20, 28.84, None],
#     [21, 36.97, None],
#     [22, 32.89, None],
#     [23, 31.53, None],
#     [24, 31.26, None],
#     [25, 38.31, None],
#     [26, 35.22, None],
#     [27, 36.06, None],
#     [28, 35.95, None],
#     [29, 37.54, None],
#     [30, 37.3, None],
#     [31, 36.98, None],
#     [32, 36.97, None],
#     [33, 40.5, None],
#     [34, 40.71, None],
#     [35, 42.22, None],
#     [36, 42.73, None],
#     [37, 45.25, None],
#     [38, 41.8, None],
#     [39, 40.6, None],
#     [40, 40.99, None],
#     [41, 41.34, None],
#     [42, 40.17, None],
#     [43, 39.29, None],
#     [44, 39.19, None],
#     [45, 39.71, None],
#     [46, 37.83, None],
#     [None, None, None],
#     [None, None, None]],
#    'label': '半導體業'}],
#  'showNameList': ['2330 台積電 (上市半導體業)'],
#  'checkedNameList': ['2330 台積電 (上市半導體業)', '公司平均數', '半導體業'],
#  'extraNameList': ['公司平均數', '半導體業'],
#  'displayCompanyId': ['2330 台積電 (上市半導體業)', '公司平均數', '半導體業']}

# %%
import json
import pandas as pd

data = response.json()

data = json.loads(data["json"])
quarters_amount = len(data["graphData"][-1]["data"]) - 1
year = 2013
quarter = 1
quarters = []
for _ in range(quarters_amount):
    quarters.append(f"{year}Q{quarter}")
    quarter += 1
    if quarter > 4:
        quarter = 1
        year += 1

data
# data
# df = pd.DataFrame()
# df["Quarters"] = quarters

# company_name_list = ["Quarters"]
# for i in range(3):
#     company_data = data["graphData"][i]["data"]
#     company_name = data["graphData"][i]["label"]
#     if len(company_data) < quarters_amount:
#         # print(company_data)
#         # print(company_name)
#         company_name_list.append(company_name)
#         df2 = pd.DataFrame(data["graphData"][i]["data"])
#         df2 = df2.iloc[:, : -1]
#         df2.set_index(0, inplace = True)
#         df = pd.concat([df, df2], axis = 1)

# df.columns = company_name_list
# df.fillna(0, axis = 1, inplace = True)

# df
# Out:
# {'xaxisList': ['2013Q1',
#   '2013Q2',
#   '2013Q3',
#   '2013Q4',
#   '2014Q1',
#   '2014Q2',
#   '2014Q3',
#   '2014Q4',
#   '2015Q1',
#   '2015Q2',
#   '2015Q3',
#   '2015Q4',
#   '2016Q1',
#   '2016Q2',
#   '2016Q3',
#   '2016Q4',
#   '2017Q1',
#   '2017Q2',
#   '2017Q3',
#   '2017Q4',
#   '2018Q1',
#   '2018Q2',
#   '2018Q3',
#   '2018Q4',
#   '2019Q1',
#   '2019Q2',
#   '2019Q3',
#   '2019Q4',
#   '2020Q1',
#   '2020Q2',
#   '2020Q3',
#   '2020Q4',
#   '2021Q1',
#   '2021Q2',
#   '2021Q3',
#   '2021Q4',
#   '2022Q1',
#   '2022Q2',
#   '2022Q3',
#   '2022Q4',
#   '2023Q1',
#   '2023Q2',
#   '2023Q3',
#   '2023Q4',
#   '2024Q1',
#   '2024Q2',
#   '2024Q3'],
#  'ylabel': '%',
#  'yaxisLabel': '',
#  'graphData': [{'data': [[0, 27.6, 'C'],
#     [1, 36.21, 'C'],
#     [2, 31.71, 'C'],
#     [3, 32.88, 'C'],
#     [4, 30.86, 'C'],
#     [5, 34.8, 'C'],
#     [6, 29.14, 'C'],
#     [7, 30.06, 'C'],
#     [8, 27.81, 'C'],
#     [9, 33.7, 'C'],
#     [10, 26.98, 'C'],
#     [11, 26.24, 'C'],
#     [12, 25.81, 'C'],
#     [13, 33.65, 'C'],
#     [14, 25.3, 'C'],
#     [15, 26.31, 'C'],
#     [16, 24.73, 'C'],
#     [17, 32.42, 'C'],
#     [18, 22.27, 'C'],
#     [19, 23.55, 'C'],
#     [20, 21.6, 'C'],
#     [21, 27.41, 'C'],
#     [22, 20.0, 'C'],
#     [23, 19.74, 'C'],
#     [24, 20.29, 'C'],
#     [25, 30.59, 'C'],
#     [26, 25.62, 'C'],
#     [27, 28.38, 'C'],
#     [28, 28.43, 'C'],
#     [29, 29.71, 'C'],
#     [30, 32.15, 'C'],
#     [31, 32.97, 'C'],
#     [32, 33.51, 'C'],
#     [33, 35.53, 'C'],
#     [34, 37.63, 'C'],
#     [35, 41.73, 'C'],
#     [36, 41.86, 'C'],
#     [37, 42.23, 'C'],
#     [38, 40.73, 'C'],
#     [39, 40.37, 'C'],
#     [40, 38.7, 'C'],
#     [41, 37.75, 'C'],
#     [42, 38.5, 'C'],
#     [43, 37.04, 'C'],
#     [44, 36.67, 'C'],
#     [45, 36.14, 'C'],
#     [46, 34.77, 'C']],
#    'label': '台積電'},
#   {'data': [[0, 27.6, 'C'],
#     [1, 36.21, 'C'],
#     [2, 31.71, 'C'],
#     [3, 32.88, 'C'],
#     [4, 30.86, 'C'],
#     [5, 34.8, 'C'],
#     [6, 29.14, 'C'],
#     [7, 30.06, 'C'],
#     [8, 27.81, 'C'],
#     [9, 33.7, 'C'],
#     [10, 26.98, 'C'],
#     [11, 26.24, 'C'],
#     [12, 25.81, 'C'],
#     [13, 33.65, 'C'],
#     [14, 25.3, 'C'],
#     [15, 26.31, 'C'],
#     [16, 24.73, 'C'],
#     [17, 32.42, 'C'],
#     [18, 22.27, 'C'],
#     [19, 23.55, 'C'],
#     [20, 21.6, 'C'],
#     [21, 27.41, 'C'],
#     [22, 20.0, 'C'],
#     [23, 19.74, 'C'],
#     [24, 20.29, 'C'],
#     [25, 30.59, 'C'],
#     [26, 25.62, 'C'],
#     [27, 28.38, 'C'],
#     [28, 28.43, 'C'],
#     [29, 29.71, 'C'],
#     [30, 32.15, 'C'],
#     [31, 32.97, 'C'],
#     [32, 33.51, 'C'],
#     [33, 35.53, 'C'],
#     [34, 37.63, 'C'],
#     [35, 41.73, 'C'],
#     [36, 41.86, 'C'],
#     [37, 42.23, 'C'],
#     [38, 40.73, 'C'],
#     [39, 40.37, 'C'],
#     [40, 38.7, 'C'],
#     [41, 37.75, 'C'],
#     [42, 38.5, 'C'],
#     [43, 37.04, 'C'],
#     [44, 36.67, 'C'],
#     [45, 36.14, 'C'],
#     [46, 34.77, 'C']],
#    'label': '公司平均數'},
#   {'data': [[0, 32.01, None],
#     [1, 37.84, None],
#     [2, 34.33, None],
#     [3, 34.62, None],
#     [4, 32.94, None],
#     [5, 37.11, None],
#     [6, 33.27, None],
#     [7, 32.78, None],
#     [8, 31.06, None],
#     [9, 36.39, None],
#     [10, 31.3, None],
#     [11, 30.44, None],
#     [12, 29.93, None],
#     [13, 36.82, None],
#     [14, 31.91, None],
#     [15, 33.02, None],
#     [16, 31.72, None],
#     [17, 36.76, None],
#     [18, 30.71, None],
#     [19, 30.31, None],
#     [20, 28.84, None],
#     [21, 36.97, None],
#     [22, 32.89, None],
#     [23, 31.53, None],
#     [24, 31.26, None],
#     [25, 38.31, None],
#     [26, 35.22, None],
#     [27, 36.06, None],
#     [28, 35.95, None],
#     [29, 37.54, None],
#     [30, 37.3, None],
#     [31, 36.98, None],
#     [32, 36.97, None],
#     [33, 40.5, None],
#     [34, 40.71, None],
#     [35, 42.22, None],
#     [36, 42.73, None],
#     [37, 45.25, None],
#     [38, 41.8, None],
#     [39, 40.6, None],
#     [40, 40.99, None],
#     [41, 41.34, None],
#     [42, 40.17, None],
#     [43, 39.29, None],
#     [44, 39.19, None],
#     [45, 39.71, None],
#     [46, 37.83, None],
#     [None, None, None],
#     [None, None, None]],
#    'label': '半導體業'}],
#  'showNameList': ['2330 台積電 (上市半導體業)'],
#  'checkedNameList': ['2330 台積電 (上市半導體業)', '公司平均數', '半導體業'],
#  'extraNameList': ['公司平均數', '半導體業']}

# %%
a = [5]
b = [6]
a.extend(b)
a
# Out:
# [5, 6]

# %%
quarters = data["xaxisList"]
quarters
# Out:
# ['2013Q1',
#  '2013Q2',
#  '2013Q3',
#  '2013Q4',
#  '2014Q1',
#  '2014Q2',
#  '2014Q3',
#  '2014Q4',
#  '2015Q1',
#  '2015Q2',
#  '2015Q3',
#  '2015Q4',
#  '2016Q1',
#  '2016Q2',
#  '2016Q3',
#  '2016Q4',
#  '2017Q1',
#  '2017Q2',
#  '2017Q3',
#  '2017Q4',
#  '2018Q1',
#  '2018Q2',
#  '2018Q3',
#  '2018Q4',
#  '2019Q1',
#  '2019Q2',
#  '2019Q3',
#  '2019Q4',
#  '2020Q1',
#  '2020Q2',
#  '2020Q3',
#  '2020Q4',
#  '2021Q1',
#  '2021Q2',
#  '2021Q3',
#  '2021Q4',
#  '2022Q1',
#  '2022Q2',
#  '2022Q3',
#  '2022Q4',
#  '2023Q1',
#  '2023Q2',
#  '2023Q3',
#  '2023Q4',
#  '2024Q1',
#  '2024Q2',
#  '2024Q3']

# %%
import json
from flask import Flask, make_response
import numpy as np
import pandas as pd

data = response.json()
data = json.loads(data["json"])

quarters = data["xaxisList"]

values = data["graphData"]
full_company_names = data["checkedNameList"]

if len(stock_ids) == 1:
    quarters_json = [[] for _ in range(2)]
    full_company_names.remove("公司平均數")
    del values[1]
else:
    quarters_json = [[] for _ in range(len(values))]

df = pd.DataFrame()
df["Quarters"] = quarters

company_name_list = ["Quarters"]

for i in range(len(values)):
    company_data = data["graphData"][i]["data"]
    company_name = data["graphData"][i]["label"]
    # if len(company_data) < quarters_amount:
        # print(company_data)
        # print(company_name)
    company_name_list.append(company_name)
    df2 = pd.DataFrame(company_data)
    df2 = df2.iloc[:, : -1]
    df2 = df2.dropna(axis = 0)
    df2.set_index(0, inplace = True)
    df = pd.concat([df, df2], axis = 1)

df.columns = company_name_list

# df = df.iloc[: -1, :] # 和上面迴圈的dropna留一個就可以

for i in range(len(values)):
    for j in range(len(quarters)):
        try: 
            quarters_json[i].append({"quarter": str(quarters[j]), "value": None if pd.isna(df[company_name_list[i + 1]][j]) else round(df[company_name_list[i + 1]][j], 2)})
        except:
            pass

dict_format = {
    "companies": 
    [
        {} for _ in range(len(values))
    ]
}

for i in range(len(values)):
#     string_values_array = np.array(values[i]["data"])[: len(quarters), 1]
#     float_values_array = np.array(string_values_array, dtype = "float64")
    first_space = full_company_names[i].find(" ")
    second_space = full_company_names[i].rfind(" ")
    if (first_space and second_space) == -1:
        dict_format["companies"][i]["name"] = full_company_names[i]
        dict_format["companies"][i]["stock_id"] = full_company_names[i]
    else:
        dict_format["companies"][i]["name"] = full_company_names[i][first_space + 1: second_space]
        dict_format["companies"][i]["stock_id"] = full_company_names[i][: first_space]
    dict_format["companies"][i]["quarters"] = quarters_json[i]
    lastest_season = df[df[company_name_list[i + 1]].notna()][company_name_list[i + 1]].iloc[-1]
    last_season = df[df[company_name_list[i + 1]].notna()][company_name_list[i + 1]].iloc[-2]
    last_year_same_season = df.iloc[int(df[df[company_name_list[i + 1]].notna()].index[-1] - 4)][company_name_list[i + 1]]
    dict_format["companies"][i]["historical_data"] = [{
        "name": "歷史最低", 
        "value": round(df[company_name_list[i + 1]].min(), 2)
    }, {
        "name": "歷史最高", 
        "value": round(df[company_name_list[i + 1]].max(), 2)
    }, {
        "name": "最新一季", 
        "value": round(lastest_season, 2)
    }, {
        "name": "上一季", 
        "value": round(last_season, 2)
    }, {
        "name": "去年同季", 
        "value": round(last_year_same_season, 2)
    }]
    dict_format["companies"][i]["growth_rate"] = [{
        "name": "較上一季",
        "value": round((lastest_season - last_season) / last_season, 2)
    }, {
        "name": "較去年同季", 
        "value": round((lastest_season - last_year_same_season) / last_year_same_season, 2)
    }]


app = Flask(__name__)

@app.route("/get_ratio", methods = ["GET"])
def get_ratio():
    return json.dumps(dict_format["companies"], ensure_ascii = False, indent = 2)

app.run()
# print(json.dumps(dict_format["companies"], ensure_ascii = False, indent = 2))
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [10/Dec/2024 17:19:53] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [10/Dec/2024 17:19:53] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [10/Dec/2024 17:20:12] "GET /get_ratio HTTP/1.1" 200 -

# %%
import json

json_data = json.dumps({'name': 'Tom', 'age': None})
json_data
# Out:
# '{"name": "Tom", "age": null}'

# %%
df_test = pd.DataFrame()
df_test["哈"] = [1, 5, 6, np.NaN]
df_test["囉"] = [2, 5, 6, np.NaN]
for value in df_test["哈"]:
    if pd.isna(value):
        print(None)
    else:
        print(value)
# Out:
# 1.0
# 5.0
# 6.0
# None

# %%
import numpy as np

data = response.json()

quarters = data["xaxisList"]
# len(quarters) # 44

values = data["graphData"]
quarters_json = [[] for _ in range(len(values))]

# 以下兩個array要放入迴圈
# string_values_array = np.array(values[0]["data"])[:, 1]
# float_values_array = np.array(string_values_array, dtype = "float64")


full_company_names = data["displayCompanyId"]
# first_space = full_company_names[0].find(" ")
# second_space = full_company_names[0].rfind(" ")

for i in range(len(values)):
    for j in range(len(quarters)):
        quarters_json[i].append({"quarter": str(quarters[j]), "value": round(values[i]["data"][j][1], 2)})

dict_format = {
    "companies": 
    [
        {} for _ in range(len(values))
    ]
}

for i in range(len(values)):
    string_values_array = np.array(values[i]["data"])[: len(quarters), 1]
    float_values_array = np.array(string_values_array, dtype = "float64")
    first_space = full_company_names[i].find(" ")
    second_space = full_company_names[i].rfind(" ")
    if (first_space and second_space) == -1:
        dict_format["companies"][i]["name"] = full_company_names[i]
        dict_format["companies"][i]["stock_id"] = full_company_names[i]
    else:
        dict_format["companies"][i]["name"] = full_company_names[i][first_space + 1: second_space]
        dict_format["companies"][i]["stock_id"] = full_company_names[i][: first_space]
    dict_format["companies"][i]["quarters"] = quarters_json[i]
    dict_format["companies"][i]["historical_data"] = [{
        "name": "歷史最低", 
        "value": round(float_values_array.min(), 2)
    }, {
        "name": "歷史最高", 
        "value": round(float_values_array.max(), 2)
    }, {
        "name": "最新一季", 
        "value": round(quarters_json[i][-1]["value"], 2)
    }, {
        "name": "上一季", 
        "value": round(quarters_json[i][-2]["value"], 2)
    }, {
        "name": "去年同季", 
        "value": round(quarters_json[i][-5]["value"], 2)
    }]
    dict_format["companies"][i]["growth_rate"] = [{
        "name": "較上一季",
        "value": round((quarters_json[i][-1]["value"] - quarters_json[i][-2]["value"]) / quarters_json[i][-2]["value"], 2)
    }, {
        "name": "較去年同季", 
        "value": round((quarters_json[i][-1]["value"] - quarters_json[i][-5]["value"]) / quarters_json[i][-5]["value"], 2)
    }]

# {
#     "companies": 
#     [
#         {
#             "name": full_company_names[0][first_space + 1: second_space], 
#             "stock_id": full_company_names[0][: first_space], 
#             "quarters": quarters_json[0], 
#             "historical_data": [{
#                 "name": "歷史最低", 
#                 "value": float_values_array.min()
#             }, {
#                 "name": "歷史最高", 
#                 "value": float_values_array.max()
#             }, {
#                 "name": "最新一季", 
#                 "value": float_values_array[-1]
#             }, {
#                 "name": "上一季", 
#                 "value": float_values_array[-2]
#             }, {
#                 "name": "去年同季", 
#                 "value": float_values_array[-5]
#             }]
#         }
    
#     ]
# }
dict_format
# Out:
# {'companies': [{'name': '台積電',
#    'stock_id': '2330',
#    'quarters': [{'quarter': '2013Q1', 'value': 27.6},
#     {'quarter': '2013Q2', 'value': 36.21},
#     {'quarter': '2013Q3', 'value': 31.71},
#     {'quarter': '2013Q4', 'value': 32.88},
#     {'quarter': '2014Q1', 'value': 30.86},
#     {'quarter': '2014Q2', 'value': 34.8},
#     {'quarter': '2014Q3', 'value': 29.14},
#     {'quarter': '2014Q4', 'value': 30.06},
#     {'quarter': '2015Q1', 'value': 27.81},
#     {'quarter': '2015Q2', 'value': 33.7},
#     {'quarter': '2015Q3', 'value': 26.98},
#     {'quarter': '2015Q4', 'value': 26.24},
#     {'quarter': '2016Q1', 'value': 25.81},
#     {'quarter': '2016Q2', 'value': 33.65},
#     {'quarter': '2016Q3', 'value': 25.3},
#     {'quarter': '2016Q4', 'value': 26.31},
#     {'quarter': '2017Q1', 'value': 24.73},
#     {'quarter': '2017Q2', 'value': 32.42},
#     {'quarter': '2017Q3', 'value': 22.27},
#     {'quarter': '2017Q4', 'value': 23.55},
#     {'quarter': '2018Q1', 'value': 21.6},
#     {'quarter': '2018Q2', 'value': 27.41},
#     {'quarter': '2018Q3', 'value': 20.0},
#     {'quarter': '2018Q4', 'value': 19.74},
#     {'quarter': '2019Q1', 'value': 20.29},
#     {'quarter': '2019Q2', 'value': 30.59},
#     {'quarter': '2019Q3', 'value': 25.62},
#     {'quarter': '2019Q4', 'value': 28.38},
#     {'quarter': '2020Q1', 'value': 28.43},
#     {'quarter': '2020Q2', 'value': 29.71},
#     {'quarter': '2020Q3', 'value': 32.15},
#     {'quarter': '2020Q4', 'value': 32.97},
#     {'quarter': '2021Q1', 'value': 33.51},
#     {'quarter': '2021Q2', 'value': 35.53},
#     {'quarter': '2021Q3', 'value': 37.63},
#     {'quarter': '2021Q4', 'value': 41.73},
#     {'quarter': '2022Q1', 'value': 41.86},
#     {'quarter': '2022Q2', 'value': 42.23},
#     {'quarter': '2022Q3', 'value': 40.73},
#     {'quarter': '2022Q4', 'value': 40.37},
#     {'quarter': '2023Q1', 'value': 38.7},
#     {'quarter': '2023Q2', 'value': 37.75},
#     {'quarter': '2023Q3', 'value': 38.5},
#     {'quarter': '2023Q4', 'value': 37.04},
#     {'quarter': '2024Q1', 'value': 36.67},
#     {'quarter': '2024Q2', 'value': 36.14},
#     {'quarter': '2024Q3', 'value': 34.77}],
#    'historical_data': [{'name': '歷史最低', 'value': 19.74},
#     {'name': '歷史最高', 'value': 42.23},
#     {'name': '最新一季', 'value': 34.77},
#     {'name': '上一季', 'value': 36.14},
#     {'name': '去年同季', 'value': 38.5}],
#    'growth_rate': [{'name': '較上一季', 'value': -0.04},
#     {'name': '較去年同季', 'value': -0.1}]},
#   {'name': '公司平均數',
#    'stock_id': '公司平均數',
#    'quarters': [{'quarter': '2013Q1', 'value': 27.6},
#     {'quarter': '2013Q2', 'value': 36.21},
#     {'quarter': '2013Q3', 'value': 31.71},
#     {'quarter': '2013Q4', 'value': 32.88},
#     {'quarter': '2014Q1', 'value': 30.86},
#     {'quarter': '2014Q2', 'value': 34.8},
#     {'quarter': '2014Q3', 'value': 29.14},
#     {'quarter': '2014Q4', 'value': 30.06},
#     {'quarter': '2015Q1', 'value': 27.81},
#     {'quarter': '2015Q2', 'value': 33.7},
#     {'quarter': '2015Q3', 'value': 26.98},
#     {'quarter': '2015Q4', 'value': 26.24},
#     {'quarter': '2016Q1', 'value': 25.81},
#     {'quarter': '2016Q2', 'value': 33.65},
#     {'quarter': '2016Q3', 'value': 25.3},
#     {'quarter': '2016Q4', 'value': 26.31},
#     {'quarter': '2017Q1', 'value': 24.73},
#     {'quarter': '2017Q2', 'value': 32.42},
#     {'quarter': '2017Q3', 'value': 22.27},
#     {'quarter': '2017Q4', 'value': 23.55},
#     {'quarter': '2018Q1', 'value': 21.6},
#     {'quarter': '2018Q2', 'value': 27.41},
#     {'quarter': '2018Q3', 'value': 20.0},
#     {'quarter': '2018Q4', 'value': 19.74},
#     {'quarter': '2019Q1', 'value': 20.29},
#     {'quarter': '2019Q2', 'value': 30.59},
#     {'quarter': '2019Q3', 'value': 25.62},
#     {'quarter': '2019Q4', 'value': 28.38},
#     {'quarter': '2020Q1', 'value': 28.43},
#     {'quarter': '2020Q2', 'value': 29.71},
#     {'quarter': '2020Q3', 'value': 32.15},
#     {'quarter': '2020Q4', 'value': 32.97},
#     {'quarter': '2021Q1', 'value': 33.51},
#     {'quarter': '2021Q2', 'value': 35.53},
#     {'quarter': '2021Q3', 'value': 37.63},
#     {'quarter': '2021Q4', 'value': 41.73},
#     {'quarter': '2022Q1', 'value': 41.86},
#     {'quarter': '2022Q2', 'value': 42.23},
#     {'quarter': '2022Q3', 'value': 40.73},
#     {'quarter': '2022Q4', 'value': 40.37},
#     {'quarter': '2023Q1', 'value': 38.7},
#     {'quarter': '2023Q2', 'value': 37.75},
#     {'quarter': '2023Q3', 'value': 38.5},
#     {'quarter': '2023Q4', 'value': 37.04},
#     {'quarter': '2024Q1', 'value': 36.67},
#     {'quarter': '2024Q2', 'value': 36.14},
#     {'quarter': '2024Q3', 'value': 34.77}],
#    'historical_data': [{'name': '歷史最低', 'value': 19.74},
#     {'name': '歷史最高', 'value': 42.23},
#     {'name': '最新一季', 'value': 34.77},
#     {'name': '上一季', 'value': 36.14},
#     {'name': '去年同季', 'value': 38.5}],
#    'growth_rate': [{'name': '較上一季', 'value': -0.04},
#     {'name': '較去年同季', 'value': -0.1}]},
#   {'name': '半導體業',
#    'stock_id': '半導體業',
#    'quarters': [{'quarter': '2013Q1', 'value': 32.01},
#     {'quarter': '2013Q2', 'value': 37.84},
#     {'quarter': '2013Q3', 'value': 34.33},
#     {'quarter': '2013Q4', 'value': 34.62},
#     {'quarter': '2014Q1', 'value': 32.94},
#     {'quarter': '2014Q2', 'value': 37.11},
#     {'quarter': '2014Q3', 'value': 33.27},
#     {'quarter': '2014Q4', 'value': 32.78},
#     {'quarter': '2015Q1', 'value': 31.06},
#     {'quarter': '2015Q2', 'value': 36.39},
#     {'quarter': '2015Q3', 'value': 31.3},
#     {'quarter': '2015Q4', 'value': 30.44},
#     {'quarter': '2016Q1', 'value': 29.93},
#     {'quarter': '2016Q2', 'value': 36.82},
#     {'quarter': '2016Q3', 'value': 31.91},
#     {'quarter': '2016Q4', 'value': 33.02},
#     {'quarter': '2017Q1', 'value': 31.72},
#     {'quarter': '2017Q2', 'value': 36.76},
#     {'quarter': '2017Q3', 'value': 30.71},
#     {'quarter': '2017Q4', 'value': 30.31},
#     {'quarter': '2018Q1', 'value': 28.84},
#     {'quarter': '2018Q2', 'value': 36.97},
#     {'quarter': '2018Q3', 'value': 32.89},
#     {'quarter': '2018Q4', 'value': 31.53},
#     {'quarter': '2019Q1', 'value': 31.26},
#     {'quarter': '2019Q2', 'value': 38.31},
#     {'quarter': '2019Q3', 'value': 35.22},
#     {'quarter': '2019Q4', 'value': 36.06},
#     {'quarter': '2020Q1', 'value': 35.95},
#     {'quarter': '2020Q2', 'value': 37.54},
#     {'quarter': '2020Q3', 'value': 37.3},
#     {'quarter': '2020Q4', 'value': 36.98},
#     {'quarter': '2021Q1', 'value': 36.97},
#     {'quarter': '2021Q2', 'value': 40.5},
#     {'quarter': '2021Q3', 'value': 40.71},
#     {'quarter': '2021Q4', 'value': 42.22},
#     {'quarter': '2022Q1', 'value': 42.73},
#     {'quarter': '2022Q2', 'value': 45.25},
#     {'quarter': '2022Q3', 'value': 41.8},
#     {'quarter': '2022Q4', 'value': 40.6},
#     {'quarter': '2023Q1', 'value': 40.99},
#     {'quarter': '2023Q2', 'value': 41.34},
#     {'quarter': '2023Q3', 'value': 40.17},
#     {'quarter': '2023Q4', 'value': 39.29},
#     {'quarter': '2024Q1', 'value': 39.19},
#     {'quarter': '2024Q2', 'value': 39.71},
#     {'quarter': '2024Q3', 'value': 37.83}],
#    'historical_data': [{'name': '歷史最低', 'value': 28.84},
#     {'name': '歷史最高', 'value': 45.25},
#     {'name': '最新一季', 'value': 37.83},
#     {'name': '上一季', 'value': 39.71},
#     {'name': '去年同季', 'value': 40.17}],
#    'growth_rate': [{'name': '較上一季', 'value': -0.05},
#     {'name': '較去年同季', 'value': -0.06}]}]}

# %%
import json

app = Flask(__name__)

@app.route("/get_ratio", methods = ["GET"])
def get_ratio():
    data = response.json()

    quarters = data["xaxisList"]

    values = data["graphData"]
    quarters_json = [[] for _ in range(len(values))]

    full_company_names = data["displayCompanyId"]

    for i in range(len(values)):
        for j in range(len(quarters)):
            quarters_json[i].append({"quarter": str(quarters[j]), "value": round(values[i]["data"][j][1], 2)})

    dict_format = {
        "companies": 
        [
            {} for _ in range(len(values))
        ]
    }

    print(dict_format)

    for i in range(len(values)):
        string_values_array = np.array(values[i]["data"])[: len(quarters), 1]
        float_values_array = np.array(string_values_array, dtype = "float64")
        first_space = full_company_names[i].find(" ")
        second_space = full_company_names[i].rfind(" ")
        if (first_space and second_space) == -1:
            dict_format["companies"][i]["name"] = full_company_names[i]
            dict_format["companies"][i]["stock_id"] = full_company_names[i]
        else:
            dict_format["companies"][i]["name"] = full_company_names[i][first_space + 1: second_space]
            dict_format["companies"][i]["stock_id"] = full_company_names[i][: first_space]
        dict_format["companies"][i]["quarters"] = quarters_json[i]
        dict_format["companies"][i]["historical_data"] = [{
            "name": "歷史最低", 
            "value": round(float_values_array.min(), 2)
        }, {
            "name": "歷史最高", 
            "value": round(float_values_array.max(), 2)
        }, {
            "name": "最新一季", 
            "value": round(quarters_json[i][-1]["value"], 2)
        }, {
            "name": "上一季", 
            "value": round(quarters_json[i][-2]["value"], 2)
        }, {
            "name": "去年同季", 
            "value": round(quarters_json[i][-5]["value"], 2)
        }]
        dict_format["companies"][i]["growth_rate"] = [{
            "name": "較上一季",
            "value": round((quarters_json[i][-1]["value"] - quarters_json[i][-2]["value"]) / quarters_json[i][-2]["value"], 2)
        }, {
            "name": "較去年同季", 
            "value": round((quarters_json[i][-1]["value"] - quarters_json[i][-5]["value"]) / quarters_json[i][-5]["value"], 2)
        }]

        print(json.dumps(dict_format, ensure_ascii = False, indent = 2))
        return json.dumps(dict_format, ensure_ascii = False, indent = 2)
    
app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [07/Dec/2024 10:21:09] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [07/Dec/2024 10:21:16] "GET /get_ratio HTTP/1.1" 200 -
# {'companies': [{}, {}, {}]}
# {
#   "companies": [
#     {
#       "name": "台積電",
#       "stock_id": "2330",
#       "quarters": [
#         {
#           "quarter": "2013Q1",
#           "value": 27.6
#         },
#         {
#           "quarter": "2013Q2",
#           "value": 36.21
#         },
#         {
#           "quarter": "2013Q3",
#           "value": 31.71
#         },
#         {
#           "quarter": "2013Q4",
#           "value": 32.88
#         },
#         {
#           "quarter": "2014Q1",
#           "value": 30.86
#         },
#         {
#           "quarter": "2014Q2",
#           "value": 34.8
#         },
#         {
#           "quarter": "2014Q3",
#           "value": 29.14
#         },
#         {
#           "quarter": "2014Q4",
#           "value": 30.06
#         },
#         {
#           "quarter": "2015Q1",
#           "value": 27.81
#         },
#         {
#           "quarter": "2015Q2",
#           "value": 33.7
#         },
#         {
#           "quarter": "2015Q3",
#           "value": 26.98
#         },
#         {
#           "quarter": "2015Q4",
#           "value": 26.24
#         },
#         {
#           "quarter": "2016Q1",
#           "value": 25.81
#         },
#         {
#           "quarter": "2016Q2",
#           "value": 33.65
#         },
#         {
#           "quarter": "2016Q3",
#           "value": 25.3
#         },
#         {
#           "quarter": "2016Q4",
#           "value": 26.31
#         },
#         {
#           "quarter": "2017Q1",
#           "value": 24.73
#         },
#         {
#           "quarter": "2017Q2",
#           "value": 32.42
#         },
#         {
#           "quarter": "2017Q3",
#           "value": 22.27
#         },
#         {
#           "quarter": "2017Q4",
#           "value": 23.55
#         },
#         {
#           "quarter": "2018Q1",
#           "value": 21.6
#         },
#         {
#           "quarter": "2018Q2",
#           "value": 27.41
#         },
#         {
#           "quarter": "2018Q3",
#           "value": 20.0
#         },
#         {
#           "quarter": "2018Q4",
#           "value": 19.74
#         },
#         {
#           "quarter": "2019Q1",
#           "value": 20.29
#         },
#         {
#           "quarter": "2019Q2",
#           "value": 30.59
#         },
#         {
#           "quarter": "2019Q3",
#           "value": 25.62
#         },
#         {
#           "quarter": "2019Q4",
#           "value": 28.38
#         },
#         {
#           "quarter": "2020Q1",
#           "value": 28.43
#         },
#         {
#           "quarter": "2020Q2",
#           "value": 29.71
#         },
#         {
#           "quarter": "2020Q3",
#           "value": 32.15
#         },
#         {
#           "quarter": "2020Q4",
#           "value": 32.97
#         },
#         {
#           "quarter": "2021Q1",
#           "value": 33.51
#         },
#         {
#           "quarter": "2021Q2",
#           "value": 35.53
#         },
#         {
#           "quarter": "2021Q3",
#           "value": 37.63
#         },
#         {
#           "quarter": "2021Q4",
#           "value": 41.73
#         },
#         {
#           "quarter": "2022Q1",
#           "value": 41.86
#         },
#         {
#           "quarter": "2022Q2",
#           "value": 42.23
#         },
#         {
#           "quarter": "2022Q3",
#           "value": 40.73
#         },
#         {
#           "quarter": "2022Q4",
#           "value": 40.37
#         },
#         {
#           "quarter": "2023Q1",
#           "value": 38.7
#         },
#         {
#           "quarter": "2023Q2",
#           "value": 37.75
#         },
#         {
#           "quarter": "2023Q3",
#           "value": 38.5
#         },
#         {
#           "quarter": "2023Q4",
#           "value": 37.04
#         },
#         {
#           "quarter": "2024Q1",
#           "value": 36.67
#         },
#         {
#           "quarter": "2024Q2",
#           "value": 36.14
#         },
#         {
#           "quarter": "2024Q3",
#           "value": 34.77
#         }
#       ],
#       "historical_data": [
#         {
#           "name": "歷史最低",
#           "value": 19.74
#         },
#         {
#           "name": "歷史最高",
#           "value": 42.23
#         },
#         {
#           "name": "最新一季",
#           "value": 34.77
#         },
#         {
#           "name": "上一季",
#           "value": 36.14
#         },
#         {
#           "name": "去年同季",
#           "value": 38.5
#         }
#       ],
#       "growth_rate": [
#         {
#           "name": "較上一季",
#           "value": -0.04
#         },
#         {
#           "name": "較去年同季",
#           "value": -0.1
#         }
#       ]
#     },
#     {},
#     {}
#   ]
# }

# %%
dict_format = {
    "companies": 
    [
        {} for _ in range(len(values))
    ]
}
dict_format["companies"][1]["test"] = 5
dict_format
# Out:
# {'companies': [{}, {'test': 5}, {}]}

# %%
import json

print(json.dumps(dict_format, ensure_ascii = False))
with open("2330_test.json", "w", encoding = "utf-8") as file:
    json.dump(dict_format, fp = file, ensure_ascii = False, indent = 2)
# Out:
# {"companies": [{}, {"test": 5}, {}]}

# %%
import json
import requests
import numpy as np
import pandas as pd

"""
以下的比率會先跟自己比再跟產業平均比。
DebtRatio 判斷是否大於0.5，大於的話再和產業平均比，再大於產業平均就示警，越小越安全。
LongTermLiabilitiesRatio 判斷是否小於1，如果再小於產業平均再警示。越小代表有較高的融資風險，但也可能是對未來樂觀；大於1代表財務結構安全性高。
CurrentRatio 判斷是否小於1，小於的話要再和產業平均比，再小於就警示。大於1是安全的，否則也要看是否大於產業平均。
QuickRatio 判斷是否小於1，小於的話要再和產業平均比，再小於就警示。大於1是安全的，否則也要看是否大於產業平均。
InterestCoverage 判斷是否小於5，小於的話要再和產業平均比，再小於就警示。
AccountsReceivableTurnover 這個不判斷
AccountsReceivableTurnoverDay 這個不判斷
InventoryTurnover 這個不判斷
InventoryTurnoverDay 這個不判斷
TotalAssetTurnover 判斷是否小於0.5，小於的話要再和產業平均比，再小於就警示。
GrossMargin 
OperatingMargin 
NetIncomeMargin 判斷這一期是否小於去年同期，是的話再和產業衰退幅度比，衰退比較大就警示。
ROA 判斷是否小於6%，小於的話，再和產業平均比，再小於就警示。
ROE 判斷是否小於8%，小於的話，再和產業平均比，再小於就警示。
OperatingCashflowToCurrentLiability 判斷是否小於100%，小於的話，再和產業平均比，再小於就警示。
OperatingCashflowToLiability 
OperatingCashflowToNetProfit 判斷是否小於80%，小於的話，再和產業平均比，再小於就警示。
"""

stock_ids = np.array(input("請輸入股票代碼，並以空格區分: ").split(), dtype = int)
ratio = input("請輸入想要查看的比率: ")
data = {
    "compareItem": ratio,
    "quarter": "true",
    "ylabel": "%",
    "ys": "0",
    "revenue": "true",
    "bcodeAvg": "true",
    "companyAvg": "true",
    "companyId": list(stock_ids)
}

response = requests.post("https://mopsfin.twse.com.tw/compare/data", data = data)

data = response.json()
data = json.loads(data["json"])

quarters = data["xaxisList"]

values = data["graphData"]
full_company_names = data["checkedNameList"]

if len(stock_ids) == 1:
    quarters_json = [[] for _ in range(2)]
    full_company_names.remove("公司平均數")
    del values[1]
else:
    quarters_json = [[] for _ in range(len(values))]

df = pd.DataFrame()
df["Quarters"] = quarters
company_name_list = ["Quarters"]

for i in range(len(values)):
    company_data = data["graphData"][i]["data"]
    company_name = data["graphData"][i]["label"]
    company_name_list.append(company_name)
    df2 = pd.DataFrame(company_data)
    df2 = df2.iloc[:, : -1]
    df2 = df2.dropna(axis = 0)
    df2.set_index(0, inplace = True)
    df = pd.concat([df, df2], axis = 1)

df.columns = company_name_list

for i in range(len(values)):
    for j in range(len(quarters)):
        try: 
            quarters_json[i].append({"quarter": str(quarters[j]), "value": None if pd.isna(df[company_name_list[i + 1]][j]) else round(df[company_name_list[i + 1]][j], 2)})
        except:
            pass

df.tail()

# dict_format = {
#     "companies": 
#     [
#         {} for _ in range(len(values))
#     ]
# }

# for i in range(len(values)):
#     first_space = full_company_names[i].find(" ")
#     second_space = full_company_names[i].rfind(" ")
#     if (first_space and second_space) == -1:
#         dict_format["companies"][i]["name"] = full_company_names[i]
#         dict_format["companies"][i]["stock_id"] = full_company_names[i]
#     else:
#         dict_format["companies"][i]["name"] = full_company_names[i][first_space + 1: second_space]
#         dict_format["companies"][i]["stock_id"] = full_company_names[i][: first_space]
#     dict_format["companies"][i]["quarters"] = quarters_json[i]
#     lastest_season = df[df[company_name_list[i + 1]].notna()][company_name_list[i + 1]].iloc[-1]
#     last_season = df[df[company_name_list[i + 1]].notna()][company_name_list[i + 1]].iloc[-2]
#     last_year_same_season = df.iloc[int(df[df[company_name_list[i + 1]].notna()].index[-1] - 4)][company_name_list[i + 1]]
#     dict_format["companies"][i]["historical_data"] = [{
#         "name": "歷史最低", 
#         "value": round(df[company_name_list[i + 1]].min(), 2)
#     }, {
#         "name": "歷史最高", 
#         "value": round(df[company_name_list[i + 1]].max(), 2)
#     }, {
#         "name": "最新一季", 
#         "value": round(lastest_season, 2)
#     }, {
#         "name": "上一季", 
#         "value": round(last_season, 2)
#     }, {
#         "name": "去年同季", 
#         "value": round(last_year_same_season, 2)
#     }]
#     dict_format["companies"][i]["growth_rate"] = [{
#         "name": "較上一季",
#         "value": round((lastest_season - last_season) / last_season, 2)
#     }, {
#         "name": "較去年同季", 
#         "value": round((lastest_season - last_year_same_season) / last_year_same_season, 2)
#     }] 
# 2317 2330 6214
# 3413 5347 6770
# 1269 2412 3045
# Out:
#      Quarters    鴻海    台積電    精誠      公司平均數  其他電子業  半導體業   資訊服務業
# 42.0   2023Q3  3.08  38.56  4.26  15.300000   9.57  6.64  -76.09
# 43.0   2023Q4  3.15  38.10  2.86  14.703334  -3.97 -8.40   14.77
# 44.0   2024Q1  1.88  38.00  6.73  15.536667   3.52  6.41  278.77
# 45.0   2024Q2  2.51  36.77  5.42  14.899999   5.79  4.76  -20.33
# 46.0   2024Q3  2.98  42.79  5.15  16.973333   3.06  6.46  480.86

# %%
print(full_company_names)
company_name_list
# Out:
# ['2317 鴻海 (上市其他電子業)', '2330 台積電 (上市半導體業)', '6214 精誠 (上市資訊服務業)', '公司平均數', '其他電子業', '半導體業', '資訊服務業']
# ['Quarters', '鴻海', '台積電', '精誠', '公司平均數', '其他電子業', '半導體業', '資訊服務業']

# %%
industry_list = full_company_names.copy()
# industry_list
for i in range(len(stock_ids)):
    # print(industry_list[i])
    left_parenthesis_index = industry_list[i].find("(")
    right_parenthesis_index = industry_list[i].find(")")
    industry = industry_list[i][left_parenthesis_index + 3: right_parenthesis_index]
    # industry_list[i] = industry_list[i][left_parenthesis_index + 3: right_parenthesis_index]
    # print(industry)

    company_name = company_name_list[i + 1]
    print(company_name)

    # print(df[company_name].iloc[-1])
    # print(df[industry].iloc[-1])
    if ratio == "DebtRatio":
        if df[company_name].iloc[-1] > 50:
            if df[company_name].iloc[-1] > df[industry].iloc[-1]:
                print("Y")
            else:
                print("N")
        else:
            print("N")
    elif ratio == "LongTermLiabilitiesRatio"or ratio == "CurrentRatio" or ratio == "QuickRatio":
        if df[company_name].iloc[-1] < 100:
            if df[company_name].iloc[-1] < df[industry].iloc[-1]:
                print("Y")
            else:
                print("N")
        else:
            print("N")
    elif ratio == "InterestCoverage":
        if df[company_name].iloc[-1] < 5:
            if df[company_name].iloc[-1] < df[industry].iloc[-1]:
                print("Y")
            else:
                print("N")
        else:
            print("N")
    elif ratio == "TotalAssetTurnover":
        if df[company_name].iloc[-1] < 0.5:
            if df[company_name].iloc[-1] < df[industry].iloc[-1]:
                print("Y")
            else:
                print("N")
        else:
            print("N")
    elif ratio == "NetIncomeMargin" or ratio == "GrossMargin":
        if df[company_name].iloc[-1] < df[company_name].iloc[-5]:
            if ((df[company_name].iloc[-1] - df[company_name].iloc[-5]) / df[company_name].iloc[-5]) < ((df[industry].iloc[-1] - df[industry].iloc[-5]) / df[industry].iloc[-5]):
                print("Y")
            else:
                print("N")
        else:
            print("N")
    elif ratio == "ROA":
        if df[company_name].iloc[-1] < 0.06:
            if df[company_name].iloc[-1] < df[industry].iloc[-1]:
                print("Y")
            else:
                print("N")
        else:
            print("N")
    elif ratio == "ROE":
        if df[company_name].iloc[-1] < 0.08:
            if df[company_name].iloc[-1] < df[industry].iloc[-1]:
                print("Y")
            else:
                print("N")
        else:
            print("N")  
    elif ratio == "OperatingCashflowToCurrentLiability":
        if df[company_name].iloc[-1] < 1:
            if df[company_name].iloc[-1] < df[industry].iloc[-1]:
                print("Y")
            else:
                print("N")
        else:
            print("N")        
    elif ratio == "OperatingCashflowToNetProfit":
        if df[company_name].iloc[-1] < 0.8:
            if df[company_name].iloc[-1] < df[industry].iloc[-1]:
                print("Y")
            else:
                print("N")
        else:
            print("N")
# Out:
# 鴻海
# N
# 台積電
# N
# 精誠
# N

# %% [markdown]
# # GenAI

# %% [markdown]
# ## 財務比率分析

# %%
import json
import requests
import numpy as np
import pandas as pd
from flask import Flask
from openai import OpenAI

app = Flask(__name__)

@app.route("/get_ratio", methods = ["GET"])
def get_ratio():
    stock_ids = np.array(input("請輸入股票代碼，並以空格區分: ").split(), dtype = int)
    ratio = input("請輸入想要查看的比率: ")
    """
    DebtRatio
    LongTermLiabilitiesRatio
    CurrentRatio
    QuickRatio
    InterestCoverage
    AccountsReceivableTurnover
    AccountsReceivableTurnoverDay
    InventoryTurnover
    InventoryTurnoverDay
    TotalAssetTurnover
    GrossMargin
    OperatingMargin
    NetIncomeMargin
    ROA
    ROE
    OperatingCashflowToCurrentLiability
    OperatingCashflowToLiability
    OperatingCashflowToNetProfit
    """
    data = {
        "compareItem": ratio,
        "quarter": "true",
        "ylabel": "%",
        "ys": "0",
        "revenue": "true",
        "bcodeAvg": "true",
        "companyAvg": "true",
        "companyId": list(stock_ids)
    }

    response = requests.post("https://mopsfin.twse.com.tw/compare/data", data = data)

    data = response.json()
    data = json.loads(data["json"])

    quarters = data["xaxisList"]

    values = data["graphData"]
    full_company_names = data["checkedNameList"]

    if len(stock_ids) == 1:
        quarters_json = [[] for _ in range(2)]
        full_company_names.remove("公司平均數")
        del values[1]
    else:
        quarters_json = [[] for _ in range(len(values))]

    df = pd.DataFrame()
    df["Quarters"] = quarters
    company_name_list = ["Quarters"]

    for i in range(len(values)):
        company_data = data["graphData"][i]["data"]
        company_name = data["graphData"][i]["label"]
        company_name_list.append(company_name)
        df2 = pd.DataFrame(company_data)
        df2 = df2.iloc[:, : -1]
        df2 = df2.dropna(axis = 0)
        df2.set_index(0, inplace = True)
        df = pd.concat([df, df2], axis = 1)

    df.columns = company_name_list

    for i in range(len(values)):
        for j in range(len(quarters)):
            try: 
                quarters_json[i].append({"quarter": str(quarters[j]), "value": None if pd.isna(df[company_name_list[i + 1]][j]) else round(df[company_name_list[i + 1]][j], 2)})
            except:
                pass

    dict_format = {
        "companies": 
        [
            {} for _ in range(len(values))
        ]
    }

    for i in range(len(values)):
        first_space = full_company_names[i].find(" ")
        second_space = full_company_names[i].rfind(" ")
        if (first_space and second_space) == -1:
            dict_format["companies"][i]["name"] = full_company_names[i]
            dict_format["companies"][i]["stock_id"] = full_company_names[i]
        else:
            dict_format["companies"][i]["name"] = full_company_names[i][first_space + 1: second_space]
            dict_format["companies"][i]["stock_id"] = full_company_names[i][: first_space]
        dict_format["companies"][i]["quarters"] = quarters_json[i]
        lastest_season = df[df[company_name_list[i + 1]].notna()][company_name_list[i + 1]].iloc[-1]
        last_season = df[df[company_name_list[i + 1]].notna()][company_name_list[i + 1]].iloc[-2]
        last_year_same_season = df.iloc[int(df[df[company_name_list[i + 1]].notna()].index[-1] - 4)][company_name_list[i + 1]]
        dict_format["companies"][i]["historical_data"] = [{
            "name": "歷史最低", 
            "value": round(df[company_name_list[i + 1]].min(), 2)
        }, {
            "name": "歷史最高", 
            "value": round(df[company_name_list[i + 1]].max(), 2)
        }, {
            "name": "最新一季", 
            "value": round(lastest_season, 2)
        }, {
            "name": "上一季", 
            "value": round(last_season, 2)
        }, {
            "name": "去年同季", 
            "value": round(last_year_same_season, 2)
        }]
        dict_format["companies"][i]["growth_rate"] = [{
            "name": "較上一季",
            "value": round((lastest_season - last_season) / last_season, 2)
        }, {
            "name": "較去年同季", 
            "value": round((lastest_season - last_year_same_season) / last_year_same_season, 2)
        }]
    return json.dumps(dict_format["companies"], ensure_ascii = False, indent = 2)

@app.route("/get_analysis", methods = ["GET"])
def get_analysis():
    stock_ids = np.array(input("請輸入股票代碼，並以空格區分: ").split(), dtype = int)
    ratio = input("請輸入想要查看的比率: ")
    start = input("請輸入開始時間(YYYYQQ): ")
    end = input("請輸入結束時間(YYYYQQ): ")
    
    """
    DebtRatio
    LongTermLiabilitiesRatio
    CurrentRatio
    QuickRatio
    InterestCoverage
    AccountsReceivableTurnover
    AccountsReceivableTurnoverDay
    InventoryTurnover
    InventoryTurnoverDay
    TotalAssetTurnover
    GrossMargin
    OperatingMargin
    NetIncomeMargin
    ROA
    ROE
    OperatingCashflowToCurrentLiability
    OperatingCashflowToLiability
    OperatingCashflowToNetProfit
    """
    data = {
        "compareItem": ratio,
        "quarter": "true",
        "ylabel": "%",
        "ys": "0",
        "revenue": "true",
        "bcodeAvg": "true",
        "companyAvg": "true",
        "companyId": list(stock_ids)
    }

    response = requests.post("https://mopsfin.twse.com.tw/compare/data", data = data)

    data = response.json()
    data = json.loads(data["json"])

    quarters = data["xaxisList"]

    values = data["graphData"]
    full_company_names = data["checkedNameList"]

    if len(stock_ids) == 1:
        full_company_names.remove("公司平均數")
        del values[1]

    df = pd.DataFrame()
    df["Quarters"] = quarters
    company_name_list = ["Quarters"]

    for i in range(len(values)):
        company_data = data["graphData"][i]["data"]
        company_name = data["graphData"][i]["label"]
        company_name_list.append(company_name)
        df2 = pd.DataFrame(company_data)
        df2 = df2.iloc[:, : -1]
        df2 = df2.dropna(axis = 0)
        df2.set_index(0, inplace = True)
        df = pd.concat([df, df2], axis = 1)

    df.columns = company_name_list

    client = OpenAI(api_key = "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")
    df_test = df.set_index("Quarters").loc[start: end]

    content_message = "我會給您一到三家公司、這些公司平均以及產業平均的某項比率，請依據以下資料來進行分析並給出一份完整的分析報告:\n"
    content_message += f"公司以及平均是{company_name_list[1: ]}，比率是{ratio}，時間是{start}至{end}\n"
    content_message += f"以下是相關資料\n{df_test}\n"
    content_message += f'請給我{company_name_list[1: ]}近期的趨勢報告,請以詳細、\
        嚴謹及專業的角度撰寫此報告，並提及重要的數字佐證以及各個欄位比較的分析，reply in 繁體中文'

    reply = client.chat.completions.create(
        model = "gpt-3.5-turbo",
        # model = "gpt-4",
        messages = [
            {"role": "system", "content":  "你現在是一位專業的證券分析師, 你會統整近期的比率並進行分析, 然後生成一份專業的趨勢分析報告"},
            {"role": "user", "content": content_message} # user就是代表我們
        ]
    )
    return reply.choices[0].message.content # json.dumps(reply.choices[0].message.content, ensure_ascii = False, indent = 2)

app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [12/Dec/2024 11:00:15] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [12/Dec/2024 11:00:16] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [12/Dec/2024 11:01:06] "GET /get_analysis HTTP/1.1" 200 -

# %%
import getpass # 保密輸入套件
from openai import OpenAI, OpenAIError

api_key = getpass.getpass("請輸入金鑰：")
client = OpenAI(api_key = api_key) # 建立 OpenAI 物件 # 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

# %%
# for quarter in quarters[-5: ]:
#     print(quarter)
df_test = df.set_index("Quarters").loc["2020Q1": "2024Q1"]
df_test
# Out:
#             台積電   半導體業
# Quarters
# 2020Q1    28.43  35.95
# 2020Q2    29.71  37.54
# 2020Q3    32.15  37.30
# 2020Q4    32.97  36.98
# 2021Q1    33.51  36.97
# 2021Q2    35.53  40.50
# 2021Q3    37.63  40.71
# 2021Q4    41.73  42.22
# 2022Q1    41.86  42.73
# 2022Q2    42.23  45.25
# 2022Q3    40.73  41.80
# 2022Q4    40.37  40.60
# 2023Q1    38.70  40.99
# 2023Q2    37.75  41.34
# 2023Q3    38.50  40.17
# 2023Q4    37.04  39.29
# 2024Q1    36.67  39.19

# %%
content_message = "我會給您一到三家公司、這些公司平均以及產業平均的某項比率，請依據以下資料來進行分析並給出一份完整的分析報告:\n"
content_message += f"公司以及平均是{company_name_list[1: ]}，比率是{ratio}，時間是{quarters[-5: ]}\n"
content_message += f"以下是相關資料\n{df_test}\n"
content_message += f'請給我{company_name_list[1: ]}近期的趨勢報告,請以詳細、\
      嚴謹及專業的角度撰寫此報告，並提及重要的數字佐證以及各個欄位比較的分析，reply in 繁體中文'


reply = client.chat.completions.create(
    model = "gpt-3.5-turbo",
    # model = "gpt-4",
    messages = [
        {"role": "system", "content":  "你現在是一位專業的證券分析師, 你會統整近期的比率並進行分析, 然後生成一份專業的趨勢分析報告"},
        {"role": "user", "content": content_message} # user就是代表我們
    ], 
    stream = True
)

for chunk in reply:
    if chunk.choices[0].delta.content:
        print(chunk.choices[0].delta.content, flush = True)

# %%
print(reply.choices[0].message.content)

# %%
from openai import OpenAI

client = OpenAI(api_key = "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") # 建立 OpenAI 物件 # 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

def stream_chat_completion(messages):
    response = client.chat.completions.create(
        model = "gpt-3.5-turbo",  # 或 "gpt-4" 根據你的需求
        messages = messages,
        stream = True
    )

    for chunk in response:
        if chunk.choices[0].delta.content:
            print(chunk.choices[0].delta.content, flush = True)
            # flush = True 參數用於強制刷新輸出緩衝區，使得文字立即顯示在終端上，而不是等待緩衝區填滿或遇到新行字符時才顯示。

# 初始對話訊息
messages = [
    {"role": "system", "content": "你現在是一個友好的助手。"},
    {"role": "user", "content": "你好嗎?"}
]

# 呼叫函數以流式方式接收回覆
stream_chat_completion(messages)

# %%
from openai import OpenAI
from flask import Flask, Response, stream_with_context

client = OpenAI(api_key = "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") # 建立 OpenAI 物件 # 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

def stream_chat_completion(messages):
    response = client.chat.completions.create(
        model = "gpt-3.5-turbo",  # 或 "gpt-4" 根據你的需求
        messages = messages,
        stream = True
    )

    for chunk in response:
        if chunk.choices[0].delta.content:
            # print(chunk.choices[0].delta.content, flush = True)
            yield chunk.choices[0].delta.content.encode("utf-8")
            # print(chunk.choices[0].delta.content, flush = True)
            # flush = True 參數用於強制刷新輸出緩衝區，使得文字立即顯示在終端上，而不是等待緩衝區填滿或遇到新行字符時才顯示。



# 呼叫函數以流式方式接收回覆
app = Flask(__name__)

@app.route("/get_analysis", methods = ["GET"])
def get_analysis():
    # 初始對話訊息
    messages = [
        {"role": "system", "content": "你現在是一個友好的助手。"},
        {"role": "user", "content": "你好嗎?"}
    ]
    
    return Response(stream_with_context(stream_chat_completion(messages)), content_type = "text/plain; charset = utf-8")

app.run()

# %%
from flask import Flask, Response, stream_with_context
import time

app = Flask(__name__)

@app.route('/')
def stream_response():
    # 生成一些 streaming 的文字
    def generate_text():
        for i in range(20):
            yield f"Chunk {i}\n"
            time.sleep(1)  # 模擬處理時間

    # 使用 stream_with_context 將 streaming 回應直接送到客戶端
    return Response(stream_with_context(generate_text()), content_type='text/plain')

if __name__ == '__main__':
    app.run()

# %%
print(reply.choices[0].message.content)

# %%
import os
import json
import requests
import numpy as np
import pandas as pd
from flask import Flask
from openai import OpenAI
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

app = Flask(__name__)

@app.route("/get_ratio", methods = ["GET"])
def get_ratio():
    stock_ids = np.array(input("請輸入股票代碼，並以空格區分: ").split(), dtype = int)
    ratio = input("請輸入想要查看的比率: ")
    """
    DebtRatio
    LongTermLiabilitiesRatio
    CurrentRatio
    QuickRatio
    InterestCoverage
    AccountsReceivableTurnover
    AccountsReceivableTurnoverDay
    InventoryTurnover
    InventoryTurnoverDay
    TotalAssetTurnover
    GrossMargin
    OperatingMargin
    NetIncomeMargin
    ROA
    ROE
    OperatingCashflowToCurrentLiability
    OperatingCashflowToLiability
    OperatingCashflowToNetProfit
    """
    data = {
        "compareItem": ratio,
        "quarter": "true",
        "ylabel": "%",
        "ys": "0",
        "revenue": "true",
        "bcodeAvg": "true",
        "companyAvg": "true",
        "companyId": list(stock_ids)
    }

    response = requests.post("https://mopsfin.twse.com.tw/compare/data", data = data)

    data = response.json()
    data = json.loads(data["json"])

    quarters = data["xaxisList"]

    values = data["graphData"]
    full_company_names = data["checkedNameList"]

    if len(stock_ids) == 1:
        quarters_json = [[] for _ in range(2)]
        full_company_names.remove("公司平均數")
        del values[1]
    else:
        quarters_json = [[] for _ in range(len(values))]

    df = pd.DataFrame()
    df["Quarters"] = quarters
    company_name_list = ["Quarters"]

    for i in range(len(values)):
        company_data = data["graphData"][i]["data"]
        company_name = data["graphData"][i]["label"]
        company_name_list.append(company_name)
        df2 = pd.DataFrame(company_data)
        df2 = df2.iloc[:, : -1]
        df2 = df2.dropna(axis = 0)
        df2.set_index(0, inplace = True)
        df = pd.concat([df, df2], axis = 1)

    df.columns = company_name_list

    for i in range(len(values)):
        for j in range(len(quarters)):
            try: 
                quarters_json[i].append({"quarter": str(quarters[j]), "value": None if pd.isna(df[company_name_list[i + 1]][j]) else round(df[company_name_list[i + 1]][j], 2)})
            except:
                pass

    dict_format = {
        "companies": 
        [
            {} for _ in range(len(values))
        ]
    }

    for i in range(len(values)):
        first_space = full_company_names[i].find(" ")
        second_space = full_company_names[i].rfind(" ")
        if (first_space and second_space) == -1:
            dict_format["companies"][i]["name"] = full_company_names[i]
            dict_format["companies"][i]["stock_id"] = full_company_names[i]
        else:
            dict_format["companies"][i]["name"] = full_company_names[i][first_space + 1: second_space]
            dict_format["companies"][i]["stock_id"] = full_company_names[i][: first_space]
        dict_format["companies"][i]["quarters"] = quarters_json[i]
        lastest_season = df[df[company_name_list[i + 1]].notna()][company_name_list[i + 1]].iloc[-1]
        last_season = df[df[company_name_list[i + 1]].notna()][company_name_list[i + 1]].iloc[-2]
        last_year_same_season = df.iloc[int(df[df[company_name_list[i + 1]].notna()].index[-1] - 4)][company_name_list[i + 1]]
        dict_format["companies"][i]["historical_data"] = [{
            "name": "歷史最低", 
            "value": round(df[company_name_list[i + 1]].min(), 2)
        }, {
            "name": "歷史最高", 
            "value": round(df[company_name_list[i + 1]].max(), 2)
        }, {
            "name": "最新一季", 
            "value": round(lastest_season, 2)
        }, {
            "name": "上一季", 
            "value": round(last_season, 2)
        }, {
            "name": "去年同季", 
            "value": round(last_year_same_season, 2)
        }]
        dict_format["companies"][i]["growth_rate"] = [{
            "name": "較上一季",
            "value": round((lastest_season - last_season) / last_season, 2)
        }, {
            "name": "較去年同季", 
            "value": round((lastest_season - last_year_same_season) / last_year_same_season, 2)
        }]
    return json.dumps(dict_format["companies"], ensure_ascii = False, indent = 2)

@app.route("/get_analysis", methods = ["GET"])
def get_analysis():
    stock_ids = np.array(input("請輸入股票代碼，並以空格區分: ").split(), dtype = int)
    ratio = input("請輸入想要查看的比率: ")
    start = input("請輸入開始時間(YYYYQQ): ")
    end = input("請輸入結束時間(YYYYQQ): ")
    
    """
    DebtRatio
    LongTermLiabilitiesRatio
    CurrentRatio
    QuickRatio
    InterestCoverage
    AccountsReceivableTurnover
    AccountsReceivableTurnoverDay
    InventoryTurnover
    InventoryTurnoverDay
    TotalAssetTurnover
    GrossMargin
    OperatingMargin
    NetIncomeMargin
    ROA
    ROE
    OperatingCashflowToCurrentLiability
    OperatingCashflowToLiability
    OperatingCashflowToNetProfit
    """
    data = {
        "compareItem": ratio,
        "quarter": "true",
        "ylabel": "%",
        "ys": "0",
        "revenue": "true",
        "bcodeAvg": "true",
        "companyAvg": "true",
        "companyId": list(stock_ids)
    }

    response = requests.post("https://mopsfin.twse.com.tw/compare/data", data = data)

    data = response.json()
    data = json.loads(data["json"])

    quarters = data["xaxisList"]

    values = data["graphData"]
    full_company_names = data["checkedNameList"]

    if len(stock_ids) == 1:
        full_company_names.remove("公司平均數")
        del values[1]

    df = pd.DataFrame()
    df["Quarters"] = quarters
    company_name_list = ["Quarters"]

    for i in range(len(values)):
        company_data = data["graphData"][i]["data"]
        company_name = data["graphData"][i]["label"]
        company_name_list.append(company_name)
        df2 = pd.DataFrame(company_data)
        df2 = df2.iloc[:, : -1]
        df2 = df2.dropna(axis = 0)
        df2.set_index(0, inplace = True)
        df = pd.concat([df, df2], axis = 1)

    df.columns = company_name_list
    df_ratio = df.set_index("Quarters").loc[start: end]

    load_dotenv()
    chat_model = ChatOpenAI(model = "gpt-3.5-turbo", api_key = os.getenv("OPENAI_API_KEY"))

    prompt = ChatPromptTemplate.from_messages([
        ("system", "您現在是一位專業的證券分析師，您會統整近期的比率並進行分析，然後生成一份專業的趨勢分析報告。"),
        ("human", "我會給您一到三家公司的財務比率、這些公司的財務比率平均以及產業的財務比率平均值。"
         "請依據以下資料進行分析並給出一份完整的分析報告：\n"
         "公司以及平均名字是{company_name_list1}，比率是{ratio}，時間是{start}至{end}。\n"
         "以下是相關資料：\n{df_ratio}\n"
         "請用繁體中文給我{company_name_list2}近期的趨勢報告，並以詳細、嚴謹及專業的角度撰寫此報告，並提及重要的數字佐證以及各個欄位比較的分析。")
    ])

    str_parser = StrOutputParser()

    financial_ratio_analysis_chain = prompt | chat_model | str_parser
    response = financial_ratio_analysis_chain.invoke({"company_name_list1": company_name_list[1: ], 
                                                      "ratio": ratio, "start": start, "end": end, "df_ratio": df_ratio, 
                                                      "company_name_list2": company_name_list[1: ]})

    return response

app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [07/Dec/2024 10:59:25] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [07/Dec/2024 10:59:39] "GET /get_ratio HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Dec/2024 11:00:29] "GET /get_analysis HTTP/1.1" 200 -

# %%
import http.client

conn = http.client.HTTPConnection("127.0.0.1", 5000)  # 改用 HTTP
payload = ''
headers = {}
conn.request("GET", "/get_ratio?stock_ids=2330,2317,2464&ratio=DebtRatio", payload, headers)
res = conn.getresponse()
data = res.read()
print(data.decode("utf-8"))
# Out:
# {
#   "companies": [
#     {
#       "name": "台積電",
#       "stock_id": "2330",
#       "quarters": [
#         {
#           "quarter": "2013Q1",
#           "value": 27.6
#         },
#         {
#           "quarter": "2013Q2",
#           "value": 36.21
#         },
#         {
#           "quarter": "2013Q3",
#           "value": 31.71
#         },
#         {
#           "quarter": "2013Q4",
#           "value": 32.88
#         },
#         {
#           "quarter": "2014Q1",
#           "value": 30.86
#         },
#         {
#           "quarter": "2014Q2",
#           "value": 34.8
#         },
#         {
#           "quarter": "2014Q3",
#           "value": 29.14
#         },
#         {
#           "quarter": "2014Q4",
#           "value": 30.06
#         },
#         {
#           "quarter": "2015Q1",
#           "value": 27.81
#         },
#         {
#           "quarter": "2015Q2",
#           "value": 33.7
#         },
#         {
#           "quarter": "2015Q3",
#           "value": 26.98
#         },
#         {
#           "quarter": "2015Q4",
#           "value": 26.24
#         },
#         {
#           "quarter": "2016Q1",
#           "value": 25.81
#         },
#         {
#           "quarter": "2016Q2",
#           "value": 33.65
#         },
#         {
#           "quarter": "2016Q3",
#           "value": 25.3
#         },
#         {
#           "quarter": "2016Q4",
#           "value": 26.31
#         },
#         {
#           "quarter": "2017Q1",
#           "value": 24.73
#         },
#         {
#           "quarter": "2017Q2",
#           "value": 32.42
#         },
#         {
#           "quarter": "2017Q3",
#           "value": 22.27
#         },
#         {
#           "quarter": "2017Q4",
#           "value": 23.55
#         },
#         {
#           "quarter": "2018Q1",
#           "value": 21.6
#         },
#         {
#           "quarter": "2018Q2",
#           "value": 27.41
#         },
#         {
#           "quarter": "2018Q3",
#           "value": 20.0
#         },
#         {
#           "quarter": "2018Q4",
#           "value": 19.74
#         },
#         {
#           "quarter": "2019Q1",
#           "value": 20.29
#         },
#         {
#           "quarter": "2019Q2",
#           "value": 30.59
#         },
#         {
#           "quarter": "2019Q3",
#           "value": 25.62
#         },
#         {
#           "quarter": "2019Q4",
#           "value": 28.38
#         },
#         {
#           "quarter": "2020Q1",
#           "value": 28.43
#         },
#         {
#           "quarter": "2020Q2",
#           "value": 29.71
#         },
#         {
#           "quarter": "2020Q3",
#           "value": 32.15
#         },
#         {
#           "quarter": "2020Q4",
#           "value": 32.97
#         },
#         {
#           "quarter": "2021Q1",
#           "value": 33.51
#         },
#         {
#           "quarter": "2021Q2",
#           "value": 35.53
#         },
#         {
#           "quarter": "2021Q3",
#           "value": 37.63
#         },
#         {
#           "quarter": "2021Q4",
#           "value": 41.73
#         },
#         {
#           "quarter": "2022Q1",
#           "value": 41.86
#         },
#         {
#           "quarter": "2022Q2",
#           "value": 42.23
#         },
#         {
#           "quarter": "2022Q3",
#           "value": 40.73
#         },
#         {
#           "quarter": "2022Q4",
#           "value": 40.37
#         },
#         {
#           "quarter": "2023Q1",
#           "value": 38.7
#         },
#         {
#           "quarter": "2023Q2",
#           "value": 37.75
#         },
#         {
#           "quarter": "2023Q3",
#           "value": 38.5
#         },
#         {
#           "quarter": "2023Q4",
#           "value": 37.04
#         },
#         {
#           "quarter": "2024Q1",
#           "value": 36.67
#         },
#         {
#           "quarter": "2024Q2",
#           "value": 36.14
#         },
#         {
#           "quarter": "2024Q3",
#           "value": 34.77
#         }
#       ],
#       "historical_data": [
#         {
#           "name": "歷史最低",
#           "value": 19.74
#         },
#         {
#           "name": "歷史最高",
#           "value": 42.23
#         },
#         {
#           "name": "最新一季",
#           "value": 34.77
#         },
#         {
#           "name": "上一季",
#           "value": 36.14
#         },
#         {
#           "name": "去年同季",
#           "value": 38.5
#         }
#       ],
#       "growth_rate": [
#         {
#           "name": "較上一季",
#           "value": -0.04
#         },
#         {
#           "name": "較去年同季",
#           "value": -0.1
#         }
#       ]
#     },
#     {
#       "name": "鴻海",
#       "stock_id": "2317",
#       "quarters": [
#         {
#           "quarter": "2013Q1",
#           "value": 64.65
#         },
#         {
#           "quarter": "2013Q2",
#           "value": 62.64
#         },
#         {
#           "quarter": "2013Q3",
#           "value": 62.67
#         },
#         {
#           "quarter": "2013Q4",
#           "value": 65.15
#         },
#         {
#           "quarter": "2014Q1",
#           "value": 59.41
#         },
#         {
#           "quarter": "2014Q2",
#           "value": 57.56
#         },
#         {
#           "quarter": "2014Q3",
#           "value": 58.73
#         },
#         {
#           "quarter": "2014Q4",
#           "value": 60.02
#         },
#         {
#           "quarter": "2015Q1",
#           "value": 54.08
#         },
#         {
#           "quarter": "2015Q2",
#           "value": 57.63
#         },
#         {
#           "quarter": "2015Q3",
#           "value": 56.66
#         },
#         {
#           "quarter": "2015Q4",
#           "value": 54.06
#         },
#         {
#           "quarter": "2016Q1",
#           "value": 49.3
#         },
#         {
#           "quarter": "2016Q2",
#           "value": 52.51
#         },
#         {
#           "quarter": "2016Q3",
#           "value": 56.14
#         },
#         {
#           "quarter": "2016Q4",
#           "value": 56.26
#         },
#         {
#           "quarter": "2017Q1",
#           "value": 49.26
#         },
#         {
#           "quarter": "2017Q2",
#           "value": 53.9
#         },
#         {
#           "quarter": "2017Q3",
#           "value": 58.13
#         },
#         {
#           "quarter": "2017Q4",
#           "value": 65.61
#         },
#         {
#           "quarter": "2018Q1",
#           "value": 55.76
#         },
#         {
#           "quarter": "2018Q2",
#           "value": 56.67
#         },
#         {
#           "quarter": "2018Q3",
#           "value": 63.09
#         },
#         {
#           "quarter": "2018Q4",
#           "value": 60.59
#         },
#         {
#           "quarter": "2019Q1",
#           "value": 54.01
#         },
#         {
#           "quarter": "2019Q2",
#           "value": 56.64
#         },
#         {
#           "quarter": "2019Q3",
#           "value": 60.73
#         },
#         {
#           "quarter": "2019Q4",
#           "value": 57.85
#         },
#         {
#           "quarter": "2020Q1",
#           "value": 54.67
#         },
#         {
#           "quarter": "2020Q2",
#           "value": 57.01
#         },
#         {
#           "quarter": "2020Q3",
#           "value": 58.98
#         },
#         {
#           "quarter": "2020Q4",
#           "value": 59.88
#         },
#         {
#           "quarter": "2021Q1",
#           "value": 57.93
#         },
#         {
#           "quarter": "2021Q2",
#           "value": 56.66
#         },
#         {
#           "quarter": "2021Q3",
#           "value": 58.53
#         },
#         {
#           "quarter": "2021Q4",
#           "value": 59.75
#         },
#         {
#           "quarter": "2022Q1",
#           "value": 59.29
#         },
#         {
#           "quarter": "2022Q2",
#           "value": 59.8
#         },
#         {
#           "quarter": "2022Q3",
#           "value": 62.43
#         },
#         {
#           "quarter": "2022Q4",
#           "value": 60.07
#         },
#         {
#           "quarter": "2023Q1",
#           "value": 56.2
#         },
#         {
#           "quarter": "2023Q2",
#           "value": 57.89
#         },
#         {
#           "quarter": "2023Q3",
#           "value": 58.48
#         },
#         {
#           "quarter": "2023Q4",
#           "value": 57.2
#         },
#         {
#           "quarter": "2024Q1",
#           "value": 55.19
#         },
#         {
#           "quarter": "2024Q2",
#           "value": 56.6
#         },
#         {
#           "quarter": "2024Q3",
#           "value": 57.92
#         }
#       ],
#       "historical_data": [
#         {
#           "name": "歷史最低",
#           "value": 49.26
#         },
#         {
#           "name": "歷史最高",
#           "value": 65.61
#         },
#         {
#           "name": "最新一季",
#           "value": 57.92
#         },
#         {
#           "name": "上一季",
#           "value": 56.6
#         },
#         {
#           "name": "去年同季",
#           "value": 58.48
#         }
#       ],
#       "growth_rate": [
#         {
#           "name": "較上一季",
#           "value": 0.02
#         },
#         {
#           "name": "較去年同季",
#           "value": -0.01
#         }
#       ]
#     },
#     {
#       "name": "盟立",
#       "stock_id": "2464",
#       "quarters": [
#         {
#           "quarter": "2013Q1",
#           "value": 42.83
#         },
#         {
#           "quarter": "2013Q2",
#           "value": 45.62
#         },
#         {
#           "quarter": "2013Q3",
#           "value": 45.33
#         },
#         {
#           "quarter": "2013Q4",
#           "value": 44.77
#         },
#         {
#           "quarter": "2014Q1",
#           "value": 43.26
#         },
#         {
#           "quarter": "2014Q2",
#           "value": 47.58
#         },
#         {
#           "quarter": "2014Q3",
#           "value": 47.01
#         },
#         {
#           "quarter": "2014Q4",
#           "value": 48.24
#         },
#         {
#           "quarter": "2015Q1",
#           "value": 47.24
#         },
#         {
#           "quarter": "2015Q2",
#           "value": 54.43
#         },
#         {
#           "quarter": "2015Q3",
#           "value": 51.73
#         },
#         {
#           "quarter": "2015Q4",
#           "value": 54.57
#         },
#         {
#           "quarter": "2016Q1",
#           "value": 50.15
#         },
#         {
#           "quarter": "2016Q2",
#           "value": 58.73
#         },
#         {
#           "quarter": "2016Q3",
#           "value": 61.09
#         },
#         {
#           "quarter": "2016Q4",
#           "value": 63.3
#         },
#         {
#           "quarter": "2017Q1",
#           "value": 65.39
#         },
#         {
#           "quarter": "2017Q2",
#           "value": 70.38
#         },
#         {
#           "quarter": "2017Q3",
#           "value": 68.19
#         },
#         {
#           "quarter": "2017Q4",
#           "value": 68.36
#         },
#         {
#           "quarter": "2018Q1",
#           "value": 64.85
#         },
#         {
#           "quarter": "2018Q2",
#           "value": 67.05
#         },
#         {
#           "quarter": "2018Q3",
#           "value": 64.76
#         },
#         {
#           "quarter": "2018Q4",
#           "value": 66.87
#         },
#         {
#           "quarter": "2019Q1",
#           "value": 67.89
#         },
#         {
#           "quarter": "2019Q2",
#           "value": 67.73
#         },
#         {
#           "quarter": "2019Q3",
#           "value": 62.57
#         },
#         {
#           "quarter": "2019Q4",
#           "value": 64.49
#         },
#         {
#           "quarter": "2020Q1",
#           "value": 62.19
#         },
#         {
#           "quarter": "2020Q2",
#           "value": 65.92
#         },
#         {
#           "quarter": "2020Q3",
#           "value": 63.22
#         },
#         {
#           "quarter": "2020Q4",
#           "value": 63.34
#         },
#         {
#           "quarter": "2021Q1",
#           "value": 59.36
#         },
#         {
#           "quarter": "2021Q2",
#           "value": 57.38
#         },
#         {
#           "quarter": "2021Q3",
#           "value": 61.78
#         },
#         {
#           "quarter": "2021Q4",
#           "value": 64.23
#         },
#         {
#           "quarter": "2022Q1",
#           "value": 64.97
#         },
#         {
#           "quarter": "2022Q2",
#           "value": 65.02
#         },
#         {
#           "quarter": "2022Q3",
#           "value": 65.32
#         },
#         {
#           "quarter": "2022Q4",
#           "value": 66.87
#         },
#         {
#           "quarter": "2023Q1",
#           "value": 68.01
#         },
#         {
#           "quarter": "2023Q2",
#           "value": 66.1
#         },
#         {
#           "quarter": "2023Q3",
#           "value": 65.58
#         },
#         {
#           "quarter": "2023Q4",
#           "value": 64.77
#         },
#         {
#           "quarter": "2024Q1",
#           "value": 63.07
#         },
#         {
#           "quarter": "2024Q2",
#           "value": 62.97
#         },
#         {
#           "quarter": "2024Q3",
#           "value": 62.91
#         }
#       ],
#       "historical_data": [
#         {
#           "name": "歷史最低",
#           "value": 42.83
#         },
#         {
#           "name": "歷史最高",
#           "value": 70.38
#         },
#         {
#           "name": "最新一季",
#           "value": 62.91
#         },
#         {
#           "name": "上一季",
#           "value": 62.97
#         },
#         {
#           "name": "去年同季",
#           "value": 65.58
#         }
#       ],
#       "growth_rate": [
#         {
#           "name": "較上一季",
#           "value": -0.0
#         },
#         {
#           "name": "較去年同季",
#           "value": -0.04
#         }
#       ]
#     },
#     {
#       "name": "公司平均數",
#       "stock_id": "公司平均數",
#       "quarters": [
#         {
#           "quarter": "2013Q1",
#           "value": 45.03
#         },
#         {
#           "quarter": "2013Q2",
#           "value": 48.16
#         },
#         {
#           "quarter": "2013Q3",
#           "value": 46.57
#         },
#         {
#           "quarter": "2013Q4",
#           "value": 47.6
#         },
#         {
#           "quarter": "2014Q1",
#           "value": 44.51
#         },
#         {
#           "quarter": "2014Q2",
#           "value": 46.65
#         },
#         {
#           "quarter": "2014Q3",
#           "value": 44.96
#         },
#         {
#           "quarter": "2014Q4",
#           "value": 46.11
#         },
#         {
#           "quarter": "2015Q1",
#           "value": 43.04
#         },
#         {
#           "quarter": "2015Q2",
#           "value": 48.59
#         },
#         {
#           "quarter": "2015Q3",
#           "value": 45.12
#         },
#         {
#           "quarter": "2015Q4",
#           "value": 44.96
#         },
#         {
#           "quarter": "2016Q1",
#           "value": 41.75
#         },
#         {
#           "quarter": "2016Q2",
#           "value": 48.3
#         },
#         {
#           "quarter": "2016Q3",
#           "value": 47.51
#         },
#         {
#           "quarter": "2016Q4",
#           "value": 48.62
#         },
#         {
#           "quarter": "2017Q1",
#           "value": 46.46
#         },
#         {
#           "quarter": "2017Q2",
#           "value": 52.23
#         },
#         {
#           "quarter": "2017Q3",
#           "value": 49.53
#         },
#         {
#           "quarter": "2017Q4",
#           "value": 52.51
#         },
#         {
#           "quarter": "2018Q1",
#           "value": 47.4
#         },
#         {
#           "quarter": "2018Q2",
#           "value": 50.38
#         },
#         {
#           "quarter": "2018Q3",
#           "value": 49.28
#         },
#         {
#           "quarter": "2018Q4",
#           "value": 49.07
#         },
#         {
#           "quarter": "2019Q1",
#           "value": 47.4
#         },
#         {
#           "quarter": "2019Q2",
#           "value": 51.65
#         },
#         {
#           "quarter": "2019Q3",
#           "value": 49.64
#         },
#         {
#           "quarter": "2019Q4",
#           "value": 50.24
#         },
#         {
#           "quarter": "2020Q1",
#           "value": 48.43
#         },
#         {
#           "quarter": "2020Q2",
#           "value": 50.88
#         },
#         {
#           "quarter": "2020Q3",
#           "value": 51.45
#         },
#         {
#           "quarter": "2020Q4",
#           "value": 52.06
#         },
#         {
#           "quarter": "2021Q1",
#           "value": 50.27
#         },
#         {
#           "quarter": "2021Q2",
#           "value": 49.86
#         },
#         {
#           "quarter": "2021Q3",
#           "value": 52.65
#         },
#         {
#           "quarter": "2021Q4",
#           "value": 55.24
#         },
#         {
#           "quarter": "2022Q1",
#           "value": 55.37
#         },
#         {
#           "quarter": "2022Q2",
#           "value": 55.68
#         },
#         {
#           "quarter": "2022Q3",
#           "value": 56.16
#         },
#         {
#           "quarter": "2022Q4",
#           "value": 55.77
#         },
#         {
#           "quarter": "2023Q1",
#           "value": 54.3
#         },
#         {
#           "quarter": "2023Q2",
#           "value": 53.91
#         },
#         {
#           "quarter": "2023Q3",
#           "value": 54.19
#         },
#         {
#           "quarter": "2023Q4",
#           "value": 53.0
#         },
#         {
#           "quarter": "2024Q1",
#           "value": 51.64
#         },
#         {
#           "quarter": "2024Q2",
#           "value": 51.9
#         },
#         {
#           "quarter": "2024Q3",
#           "value": 51.87
#         }
#       ],
#       "historical_data": [
#         {
#           "name": "歷史最低",
#           "value": 41.75
#         },
#         {
#           "name": "歷史最高",
#           "value": 56.16
#         },
#         {
#           "name": "最新一季",
#           "value": 51.87
#         },
#         {
#           "name": "上一季",
#           "value": 51.9
#         },
#         {
#           "name": "去年同季",
#           "value": 54.19
#         }
#       ],
#       "growth_rate": [
#         {
#           "name": "較上一季",
#           "value": -0.0
#         },
#         {
#           "name": "較去年同季",
#           "value": -0.04
#         }
#       ]
#     },
#     {
#       "name": "半導體業",
#       "stock_id": "半導體業",
#       "quarters": [
#         {
#           "quarter": "2013Q1",
#           "value": 32.01
#         },
#         {
#           "quarter": "2013Q2",
#           "value": 37.84
#         },
#         {
#           "quarter": "2013Q3",
#           "value": 34.33
#         },
#         {
#           "quarter": "2013Q4",
#           "value": 34.62
#         },
#         {
#           "quarter": "2014Q1",
#           "value": 32.94
#         },
#         {
#           "quarter": "2014Q2",
#           "value": 37.11
#         },
#         {
#           "quarter": "2014Q3",
#           "value": 33.27
#         },
#         {
#           "quarter": "2014Q4",
#           "value": 32.78
#         },
#         {
#           "quarter": "2015Q1",
#           "value": 31.06
#         },
#         {
#           "quarter": "2015Q2",
#           "value": 36.39
#         },
#         {
#           "quarter": "2015Q3",
#           "value": 31.3
#         },
#         {
#           "quarter": "2015Q4",
#           "value": 30.44
#         },
#         {
#           "quarter": "2016Q1",
#           "value": 29.93
#         },
#         {
#           "quarter": "2016Q2",
#           "value": 36.82
#         },
#         {
#           "quarter": "2016Q3",
#           "value": 31.91
#         },
#         {
#           "quarter": "2016Q4",
#           "value": 33.02
#         },
#         {
#           "quarter": "2017Q1",
#           "value": 31.72
#         },
#         {
#           "quarter": "2017Q2",
#           "value": 36.76
#         },
#         {
#           "quarter": "2017Q3",
#           "value": 30.71
#         },
#         {
#           "quarter": "2017Q4",
#           "value": 30.31
#         },
#         {
#           "quarter": "2018Q1",
#           "value": 28.84
#         },
#         {
#           "quarter": "2018Q2",
#           "value": 36.97
#         },
#         {
#           "quarter": "2018Q3",
#           "value": 32.89
#         },
#         {
#           "quarter": "2018Q4",
#           "value": 31.53
#         },
#         {
#           "quarter": "2019Q1",
#           "value": 31.26
#         },
#         {
#           "quarter": "2019Q2",
#           "value": 38.31
#         },
#         {
#           "quarter": "2019Q3",
#           "value": 35.22
#         },
#         {
#           "quarter": "2019Q4",
#           "value": 36.06
#         },
#         {
#           "quarter": "2020Q1",
#           "value": 35.95
#         },
#         {
#           "quarter": "2020Q2",
#           "value": 37.54
#         },
#         {
#           "quarter": "2020Q3",
#           "value": 37.3
#         },
#         {
#           "quarter": "2020Q4",
#           "value": 36.98
#         },
#         {
#           "quarter": "2021Q1",
#           "value": 36.97
#         },
#         {
#           "quarter": "2021Q2",
#           "value": 40.5
#         },
#         {
#           "quarter": "2021Q3",
#           "value": 40.71
#         },
#         {
#           "quarter": "2021Q4",
#           "value": 42.22
#         },
#         {
#           "quarter": "2022Q1",
#           "value": 42.73
#         },
#         {
#           "quarter": "2022Q2",
#           "value": 45.25
#         },
#         {
#           "quarter": "2022Q3",
#           "value": 41.8
#         },
#         {
#           "quarter": "2022Q4",
#           "value": 40.6
#         },
#         {
#           "quarter": "2023Q1",
#           "value": 40.99
#         },
#         {
#           "quarter": "2023Q2",
#           "value": 41.34
#         },
#         {
#           "quarter": "2023Q3",
#           "value": 40.17
#         },
#         {
#           "quarter": "2023Q4",
#           "value": 39.29
#         },
#         {
#           "quarter": "2024Q1",
#           "value": 39.19
#         },
#         {
#           "quarter": "2024Q2",
#           "value": 39.71
#         },
#         {
#           "quarter": "2024Q3",
#           "value": 37.83
#         }
#       ],
#       "historical_data": [
#         {
#           "name": "歷史最低",
#           "value": 28.84
#         },
#         {
#           "name": "歷史最高",
#           "value": 45.25
#         },
#         {
#           "name": "最新一季",
#           "value": 37.83
#         },
#         {
#           "name": "上一季",
#           "value": 39.71
#         },
#         {
#           "name": "去年同季",
#           "value": 40.17
#         }
#       ],
#       "growth_rate": [
#         {
#           "name": "較上一季",
#           "value": -0.05
#         },
#         {
#           "name": "較去年同季",
#           "value": -0.06
#         }
#       ]
#     },
#     {
#       "name": "其他電子業",
#       "stock_id": "其他電子業",
#       "quarters": [
#         {
#           "quarter": "2013Q1",
#           "value": 59.98
#         },
#         {
#           "quarter": "2013Q2",
#           "value": 58.34
#         },
#         {
#           "quarter": "2013Q3",
#           "value": 58.31
#         },
#         {
#           "quarter": "2013Q4",
#           "value": 60.45
#         },
#         {
#           "quarter": "2014Q1",
#           "value": 55.01
#         },
#         {
#           "quarter": "2014Q2",
#           "value": 53.97
#         },
#         {
#           "quarter": "2014Q3",
#           "value": 55.15
#         },
#         {
#           "quarter": "2014Q4",
#           "value": 56.39
#         },
#         {
#           "quarter": "2015Q1",
#           "value": 51.02
#         },
#         {
#           "quarter": "2015Q2",
#           "value": 54.52
#         },
#         {
#           "quarter": "2015Q3",
#           "value": 53.56
#         },
#         {
#           "quarter": "2015Q4",
#           "value": 50.88
#         },
#         {
#           "quarter": "2016Q1",
#           "value": 47.15
#         },
#         {
#           "quarter": "2016Q2",
#           "value": 50.49
#         },
#         {
#           "quarter": "2016Q3",
#           "value": 53.3
#         },
#         {
#           "quarter": "2016Q4",
#           "value": 53.17
#         },
#         {
#           "quarter": "2017Q1",
#           "value": 46.91
#         },
#         {
#           "quarter": "2017Q2",
#           "value": 51.77
#         },
#         {
#           "quarter": "2017Q3",
#           "value": 55.38
#         },
#         {
#           "quarter": "2017Q4",
#           "value": 61.39
#         },
#         {
#           "quarter": "2018Q1",
#           "value": 52.76
#         },
#         {
#           "quarter": "2018Q2",
#           "value": 54.55
#         },
#         {
#           "quarter": "2018Q3",
#           "value": 59.75
#         },
#         {
#           "quarter": "2018Q4",
#           "value": 57.75
#         },
#         {
#           "quarter": "2019Q1",
#           "value": 51.85
#         },
#         {
#           "quarter": "2019Q2",
#           "value": 54.79
#         },
#         {
#           "quarter": "2019Q3",
#           "value": 58.14
#         },
#         {
#           "quarter": "2019Q4",
#           "value": 55.28
#         },
#         {
#           "quarter": "2020Q1",
#           "value": 52.53
#         },
#         {
#           "quarter": "2020Q2",
#           "value": 55.09
#         },
#         {
#           "quarter": "2020Q3",
#           "value": 56.71
#         },
#         {
#           "quarter": "2020Q4",
#           "value": 57.04
#         },
#         {
#           "quarter": "2021Q1",
#           "value": 55.13
#         },
#         {
#           "quarter": "2021Q2",
#           "value": 54.46
#         },
#         {
#           "quarter": "2021Q3",
#           "value": 56.26
#         },
#         {
#           "quarter": "2021Q4",
#           "value": 57.17
#         },
#         {
#           "quarter": "2022Q1",
#           "value": 57.04
#         },
#         {
#           "quarter": "2022Q2",
#           "value": 57.73
#         },
#         {
#           "quarter": "2022Q3",
#           "value": 59.63
#         },
#         {
#           "quarter": "2022Q4",
#           "value": 57.33
#         },
#         {
#           "quarter": "2023Q1",
#           "value": 54.3
#         },
#         {
#           "quarter": "2023Q2",
#           "value": 55.85
#         },
#         {
#           "quarter": "2023Q3",
#           "value": 56.08
#         },
#         {
#           "quarter": "2023Q4",
#           "value": 54.81
#         },
#         {
#           "quarter": "2024Q1",
#           "value": 53.1
#         },
#         {
#           "quarter": "2024Q2",
#           "value": 54.55
#         },
#         {
#           "quarter": "2024Q3",
#           "value": 55.01
#         }
#       ],
#       "historical_data": [
#         {
#           "name": "歷史最低",
#           "value": 46.91
#         },
#         {
#           "name": "歷史最高",
#           "value": 61.39
#         },
#         {
#           "name": "最新一季",
#           "value": 55.01
#         },
#         {
#           "name": "上一季",
#           "value": 54.55
#         },
#         {
#           "name": "去年同季",
#           "value": 56.08
#         }
#       ],
#       "growth_rate": [
#         {
#           "name": "較上一季",
#           "value": 0.01
#         },
#         {
#           "name": "較去年同季",
#           "value": -0.02
#         }
#       ]
#     }
#   ]
# }

# %%
import http.client

conn = http.client.HTTPConnection("127.0.0.1", 5000)  # 改用 HTTP
payload = ''
headers = {}
conn.request("GET", "/get_analysis?stock_ids=2330,2317,2464&ratio=DebtRatio&start=2023Q1&end=2024Q1", payload, headers)
res = conn.getresponse()
data = res.read()
print(data.decode("utf-8"))
# Out:
# ## 財務比率趨勢分析報告
#
# ### 1.  Debt Ratio（負債比率）
#
# #### 台積電：
# - 2023Q1: 38.70
# - 2023Q2: 37.75
# - 2023Q3: 38.50
# - 2023Q4: 37.04
# - 2024Q1: 36.67
#
# **趨勢分析：**
# - 台積電的負債比率在過去五個季度中呈現下降趨勢，由38.70%下降至36.67%。這表示公司在最近一年內積極減少了負債佔資產的比例，顯示其風險管理能力較為穩健。
#
# #### 鴻海：
# - 2023Q1: 56.20
# - 2023Q2: 57.89
# - 2023Q3: 58.48
# - 2023Q4: 57.20
# - 2024Q1: 55.19
#
# **趨勢分析：**
# - 鴻海的負債比率在過去五個季度中波動較大，但整體呈現輕微下降的趨勢，由56.20%降至55.19%。儘管波動較大，但整體負債比率仍在合理範圍內。
#
# #### 盟立：
# - 2023Q1: 68.01
# - 2023Q2: 66.10
# - 2023Q3: 65.58
# - 2023Q4: 64.77
# - 2024Q1: 63.07
#
# **趨勢分析：**
# - 盟立的負債比率在過去五個季度中持續下降，從68.01%降至63.07%。這顯示公司有意識地減少了負債水平，可能是為了提高資產負債表的健康度。
#
# #### 公司平均數（台積電、鴻海、盟立）：
# - 2023Q1: 54.30
# - 2023Q2: 53.91
# - 2023Q3: 54.19
# - 2023Q4: 53.00
# - 2024Q1: 51.64
#
# **趨勢分析：**
# - 三家公司的平均負債比率也呈現下降趨勢，由54.30%下降至51.64%。整體來看，這表示整個行業在過去一年中有意識地減少了負債，可能是為了應對不確定的經濟環境。
#
# #### 半導體業與其他電子業：
# - 半導體業2024Q1負債比率: 39.19
# - 其他電子業2024Q1負債比率: 53.10
#
# **比較分析：**
# - 台積電、鴻海、盟立三家公司的負債比率均低於半導體業的平均值，其中台積電和鴻海的負債比率更是遠低於其他電子業的平均值。這顯示這三家公司在負債管理方面表現較為穩健，相對於整個行業來說，風險較低。
#
# ### 結論：
# - 台積電、鴻海、盟立在過去一年中均表現出積極的負債管理策略，不斷降低負債比率，顯示其財務風險控制能力較強。
# - 整體行業的負債比率也呈現下降趨勢，顯示半導體業和其他電子業公司整體風險管理水平提升。
# - 投資者應該綜合考慮公司的負債比率以及產業的平均水平，以做出明智的投資決策。
#
# 以上為近期台積電、鴻海、盟立以及相關產業負債比率的專業趨勢分析報告，希望對您有所幫助。
